# %%
# %matplotlib inline
# changed from %matplotlib notebook as graphs werent being plotted

# %%
from Bio.Align import PairwiseAligner, substitution_matrices
from Bio.Seq import Seq 
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO
import numpy as np
from numpy import random as rd
from matplotlib import pyplot as plt

import os
import pickle
from matplotlib.ticker import MaxNLocator, ScalarFormatter, FormatStrFormatter
from matplotlib.ticker import LinearLocator
FIGSIZE = (4.5,3)
DPI = 300
N_TICKS = 3

# %%
from src.estimalign import estimalign
from src.logit_link import logit_partial_scores
from src.optimization import create_powerstep, create_constant_step

# %% [markdown]
# # Data

# %%
from miRBench.dataset import list_datasets, get_dataset_df

# %%
hejret_train = get_dataset_df(list_datasets()[0], split="train")
hejret_test = get_dataset_df(list_datasets()[0], split="test")
# Out:
# Using cached dataset /home/dave/.miRBench/datasets/14501607/AGO2_CLASH_Hejret2023/train/dataset.tsv
# Using cached dataset /home/dave/.miRBench/datasets/14501607/AGO2_CLASH_Hejret2023/test/dataset.tsv

# %%
mirlist = hejret_train['noncodingRNA']
mirlist = [Seq(seq) for seq in mirlist]
genelist = hejret_train['gene']
genelist = [Seq(seq).reverse_complement() for seq in genelist]

# %% [markdown]
# # Optimization

# %% [markdown]
# ### General matrix, affine gap penalty

# %%
true_gapopen = -1.2
true_gapext = -0.1
true_substitution = substitution_matrices.Array(alphabet='ACTG', 
                                          data=np.array([
                                              [1, -0.3, -1, -0.8], 
                                              [-0.6, 1.2, -0.3, -1], 
                                              [-1.2, -0.4, 1, -0.8], 
                                              [-0.4, -1.4, -0.9, 1.3]]))

# %%
aligner = PairwiseAligner()
aligner.mode = 'local'
aligner.open_gap_score = true_gapopen
aligner.extend_gap_score = true_gapext
aligner.substitution_matrix = true_substitution

# %%
scores = np.array([aligner.score(a, b) for a, b in zip(mirlist, genelist)])

# %%
plt.figure()
plt.hist(scores, bins=100)
plt.show()

# %%
true_alpha = -12
logit_scores = logit_partial_scores(scores, true_alpha)

# %%
plt.figure()
plt.hist(logit_scores, bins=100)
plt.show()

# %%
labels = rd.rand(len(mirlist))
labels = labels <= logit_scores
true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))
print('Sum of log-logit scores:', np.sum(np.log(logit_scores)))
print('True LogL:', true_logL)
# Out:
# Sum of log-logit scores: -11654.43085041492
# True LogL: -2968.1308504149256

# %%
const_step = create_constant_step(0.00005)
# powerstep = create_powerstep(0.00005, power=0.5, burnin=0)
powerstep = create_powerstep(0.00002, power=-0.1, burnin=0)

# %%
NITER = 200

# %%
params = estimalign(mirlist, genelist, labels, 
                    stepfunction=const_step,
                    aligner_mode='local',
                    substitution_mode='general',
                    gap_mode='affine', 
                    stochastic_factor=0.01,
                    verbose=True, max_iter=NITER,
                    num_threads = 24)
# Out:
# Alphabet:
# GCTA
# Initial parameters:
# {'alpha': np.float64(-9.431561567098456), 'substitution_matrix': Array([[ 1.12898435, -0.82586769, -0.76339196, -0.57059397],
#        [-0.75555113,  1.04695957, -0.55798324, -0.61582147],
#        [-0.76376875, -0.44454696,  0.86184593, -0.87288617],
#        [-0.67910073, -0.25523679, -0.68993416,  0.85688743]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.2219888252605928), 'extend_gap_score': np.float64(-0.07938441373656388)}
# Start of iteration 0
# Current alpha: -9.431561567098456
# Current logL: -3039.288647582825
# Updated alpha: -9.706927108400846
# Updated logL: -2999.83452507531
# New subgradient:
# {'Substitutions': Array([[159.46763494, -30.29106897, -13.65798728,  12.74307748],
#        [-20.56088688, 132.28287116,  21.54218193,  24.77720604],
#        [ -8.91653839,  21.51067108, 169.81643628, -21.06352894],
#        [ -0.9184497 ,  12.32064246, -16.92457612,  92.10687061]],
#          alphabet='GCTA'), 'Gap opens': np.float64(266.49456152107757), 'Gap extends': np.float64(323.2921314483248)}
# Stepsize: 5e-05
# Gap open step: 0.01332472807605388
# Gap extend step: 0.01616460657241624
# New parameters:
# {'alpha': np.float64(-9.706927108400846), 'substitution_matrix': Array([[ 1.13695658, -0.82738206, -0.76407459, -0.56995731],
#        [-0.75657897,  1.05357405, -0.55690652, -0.61458296],
#        [-0.76421426, -0.44347077,  0.87033692, -0.87393985],
#        [-0.67914659, -0.25462096, -0.69078017,  0.86149262]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1956609642491458), 'extend_gap_score': np.float64(-0.05670596761947865)}
# Subgradient norm: 509.875955996614
# End of iteration 0
#
# Start of iteration 1
# Current alpha: -9.706927108400846
# Current logL: -3075.256827088588
# Updated alpha: -10.108141449549038
# Updated logL: -2990.7996643142637
# New subgradient:
# {'Substitutions': Array([[123.35587032, -29.02261046,  -8.65871017,  15.81600417],
#        [-18.6325364 , 123.60070347,  14.36811299,  36.02260509],
#        [  6.35090988,  31.112647  , 105.35559919, -20.49527201],
#        [  1.97579733,   3.2937134 , -17.04055946,  68.09250564]],
#          alphabet='GCTA'), 'Gap opens': np.float64(165.74664419275538), 'Gap extends': np.float64(-463.04386118043885)}
# Stepsize: 5e-05
# Gap open step: 0.00828733220963777
# Gap extend step: -0.023152193059021945
# New parameters:
# {'alpha': np.float64(-10.108141449549038), 'substitution_matrix': Array([[ 1.14312443, -0.82883349, -0.76450733, -0.56916652],
#        [-0.7575107 ,  1.05975435, -0.55618813, -0.61278159],
#        [-0.76389677, -0.44191491,  0.87560495, -0.87496434],
#        [-0.67904773, -0.25445622, -0.69163234,  0.86489705]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.189450655644037), 'extend_gap_score': np.float64(-0.07154316389751696)}
# Subgradient norm: 541.17181253825
# End of iteration 1
#
# Start of iteration 2
# Current alpha: -10.108141449549038
# Current logL: -2984.3061804938216
# Updated alpha: -10.07651231237865
# Updated logL: -2983.7897312925757
# New subgradient:
# {'Substitutions': Array([[ 1.21541419e+02, -2.84867930e+01, -8.41837846e+00,
#          1.25524275e+01],
#        [-1.75430745e+01,  1.26890035e+02,  1.30742888e+01,
#          3.47296998e+01],
#        [ 1.03696925e-01,  2.36203767e+01,  1.41098395e+02,
#         -2.28659178e+01],
#        [ 9.54450873e-01, -1.74921109e+00, -2.00346998e+01,
#          9.70608367e+01]],
#          alphabet='GCTA'), 'Gap opens': np.float64(218.9017986918595), 'Gap extends': np.float64(98.17838689812953)}
# Stepsize: 5e-05
# Gap open step: 0.010945089934592976
# Gap extend step: 0.004908919344906477
# New parameters:
# {'alpha': np.float64(-10.07651231237865), 'substitution_matrix': Array([[ 1.14920117, -0.83025783, -0.76492812, -0.56853885],
#        [-0.75838812,  1.06609892, -0.55553474, -0.61104518],
#        [-0.76389174, -0.44073384,  0.88265989, -0.87610753],
#        [-0.6790001 , -0.25454376, -0.69263422,  0.86975023]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1818238406224606), 'extend_gap_score': np.float64(-0.06610887805464331)}
# Subgradient norm: 349.24240646626015
# End of iteration 2
#
# Start of iteration 3
# Current alpha: -10.07651231237865
# Current logL: -2995.139439332681
# Updated alpha: -10.249261757223781
# Updated logL: -2979.6796989704017
# New subgradient:
# {'Substitutions': Array([[112.44661593, -30.08654134,  -6.90856012,  17.05596453],
#        [-16.49624213, 108.08648543,  12.00488722,  34.69798225],
#        [  2.98257363,  26.34552416, 106.0256897 , -22.38397746],
#        [  4.56826175,  -6.53446185, -18.9757833 ,  86.44516846]],
#          alphabet='GCTA'), 'Gap opens': np.float64(175.61615481913455), 'Gap extends': np.float64(-281.7253308220113)}
# Stepsize: 5e-05
# Gap open step: 0.008780807740956728
# Gap extend step: -0.014086266541100565
# New parameters:
# {'alpha': np.float64(-10.249261757223781), 'substitution_matrix': Array([[ 1.15482357, -0.83176204, -0.76527367, -0.56768593],
#        [-0.75921282,  1.07150344, -0.55493447, -0.60931017],
#        [-0.7637429 , -0.43941642,  0.88796142, -0.87722675],
#        [-0.67877169, -0.25487061, -0.69358278,  0.87407247]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1712959658758315), 'extend_gap_score': np.float64(-0.08649089113812072)}
# Subgradient norm: 397.1715077708487
# End of iteration 3
#
# Start of iteration 4
# Current alpha: -10.249261757223781
# Current logL: -2978.6832390724744
# Updated alpha: -10.190539627532349
# Updated logL: -2976.9214825067647
# New subgradient:
# {'Substitutions': Array([[123.58963802, -33.65155892, -14.02131428,  16.41486553],
#        [-15.5962233 , 108.82136787,  18.13857848,  30.2763549 ],
#        [ -4.8922549 ,  23.77124121, 131.00745925, -23.44628043],
#        [ -0.9455289 ,  -0.57108084, -17.73042929,  91.74549387]],
#          alphabet='GCTA'), 'Gap opens': np.float64(207.13205546765556), 'Gap extends': np.float64(367.78600917255613)}
# Stepsize: 5e-05
# Gap open step: 0.01035660277338278
# Gap extend step: 0.018389300458627807
# New parameters:
# {'alpha': np.float64(-10.190539627532349), 'substitution_matrix': Array([[ 1.16100313, -0.83344465, -0.76597487, -0.56686521],
#        [-0.7599926 ,  1.07694453, -0.55402768, -0.60779643],
#        [-0.76398757, -0.43822786,  0.89451185, -0.87839904],
#        [-0.67881875, -0.25489909, -0.69446923,  0.87865969]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1619930533952878), 'extend_gap_score': np.float64(-0.0688286299237391)}
# Subgradient norm: 485.18967080466706
# End of iteration 4
#
# Start of iteration 5
# Current alpha: -10.190539627532349
# Current logL: -3011.1122337706497
# Updated alpha: -10.46827583597221
# Updated logL: -2971.2939975883446
# New subgradient:
# {'Substitutions': Array([[ 91.53989817, -29.7760813 ,  -6.47245084,  19.29623539],
#        [-13.44743859,  91.20545439,  10.04898803,  31.41031898],
#        [  1.74129747,  26.2248458 ,  85.90565745, -22.25334791],
#        [  3.37953832,  -5.44661191, -19.06436107,  76.36231109]],
#          alphabet='GCTA'), 'Gap opens': np.float64(129.38700789515744), 'Gap extends': np.float64(-267.6138432795383)}
# Stepsize: 5e-05
# Gap open step: 0.006469350394757872
# Gap extend step: -0.013380692163976915
# New parameters:
# {'alpha': np.float64(-10.46827583597221), 'substitution_matrix': Array([[ 1.16558005, -0.83493343, -0.76629841, -0.56590042],
#        [-0.76066505,  1.08150476, -0.55352524, -0.60622577],
#        [-0.76390054, -0.43691663,  0.89880695, -0.87951162],
#        [-0.67864987, -0.2551714 , -0.69542245,  0.8824778 ]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1559714056357682), 'extend_gap_score': np.float64(-0.08047572775110322)}
# Subgradient norm: 349.89409821219965
# End of iteration 5
#
# Start of iteration 6
# Current alpha: -10.46827583597221
# Current logL: -2968.186303377262
# Updated alpha: -10.454753288739283
# Updated logL: -2968.092973866315
# New subgradient:
# {'Substitutions': Array([[ 99.30769355, -33.40412496,  -6.69865322,  19.20096688],
#        [-14.7330384 , 100.72911497,  14.01691771,  29.85393576],
#        [ -2.68723612,  22.13684003, 104.89809717, -22.03585005],
#        [  1.35988073,  -1.01665693, -20.07700029,  76.90974975]],
#          alphabet='GCTA'), 'Gap opens': np.float64(157.20426846626074), 'Gap extends': np.float64(182.33268019867276)}
# Stepsize: 5e-05
# Gap open step: 0.007860213423313037
# Gap extend step: 0.00911663400993364
# New parameters:
# {'alpha': np.float64(-10.454753288739283), 'substitution_matrix': Array([[ 1.17054554, -0.83660365, -0.76663322, -0.56494031],
#        [-0.76140169,  1.08654116, -0.55282438, -0.6047331 ],
#        [-0.76403502, -0.4358098 ,  0.90405184, -0.88061343],
#        [-0.67858174, -0.25522218, -0.69642628,  0.88632318]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.145738141901375), 'extend_gap_score': np.float64(-0.07312996480051266)}
# Subgradient norm: 314.81463642472517
# End of iteration 6
#
# Start of iteration 7
# Current alpha: -10.454753288739283
# Current logL: -2981.4088480465794
# Updated alpha: -10.634134385751087
# Updated logL: -2964.9092753780883
# New subgradient:
# {'Substitutions': Array([[ 76.13989886, -30.36525492,  -5.40488069,  24.24541693],
#        [-16.88703406,  78.03323557,   9.7658684 ,  30.03664566],
#        [  0.31409141,  27.72976973,  77.49188951, -22.13072108],
#        [  3.25845416,  -4.80047649, -19.38184484,  73.39917284]],
#          alphabet='GCTA'), 'Gap opens': np.float64(103.97134679265508), 'Gap extends': np.float64(-219.0284183626446)}
# Stepsize: 5e-05
# Gap open step: 0.0051985673396327545
# Gap extend step: -0.01095142091813223
# New parameters:
# {'alpha': np.float64(-10.634134385751087), 'substitution_matrix': Array([[ 1.17435241, -0.83812189, -0.76690344, -0.56372798],
#        [-0.76224594,  1.09044288, -0.5523361 , -0.60323121],
#        [-0.76401925, -0.43442328,  0.90792645, -0.88172007],
#        [-0.67841892, -0.25546226, -0.69739545,  0.88999304]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1406229320404468), 'extend_gap_score': np.float64(-0.08267661536603181)}
# Subgradient norm: 294.1974651972203
# End of iteration 7
#
# Start of iteration 8
# Current alpha: -10.634134385751087
# Current logL: -2962.783053414149
# Updated alpha: -10.628932833756668
# Updated logL: -2962.76929537694
# New subgradient:
# {'Substitutions': Array([[ 86.20835738, -33.25115842, -11.79754104,  24.22476492],
#        [-11.77089009,  91.22510209,  14.78137374,  26.26034298],
#        [ -1.97069807,  24.63688372,  88.55303407, -20.934369  ],
#        [  5.40820109,  -5.88893261, -20.49909688,  71.77376507]],
#          alphabet='GCTA'), 'Gap opens': np.float64(125.71782258353439), 'Gap extends': np.float64(168.6528074386094)}
# Stepsize: 5e-05
# Gap open step: 0.00628589112917672
# Gap extend step: 0.008432640371930469
# New parameters:
# {'alpha': np.float64(-10.628932833756668), 'substitution_matrix': Array([[ 1.17866277, -0.83978438, -0.76749335, -0.56251665],
#        [-0.76283454,  1.09500423, -0.55159694, -0.60191813],
#        [-0.76411776, -0.43319142,  0.91235407, -0.8827668 ],
#        [-0.67814848, -0.25575674, -0.69842047,  0.89358172]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1332445754393687), 'extend_gap_score': np.float64(-0.0725290670029439)}
# Subgradient norm: 278.2221525050286
# End of iteration 8
#
# Start of iteration 9
# Current alpha: -10.628932833756668
# Current logL: -2979.2257203912286
# Updated alpha: -10.815438561675338
# Updated logL: -2961.4354915707145
# New subgradient:
# {'Substitutions': Array([[ 67.15100292, -29.16745061, -10.92380111,  25.99964983],
#        [-12.26375205,  56.67500106,  10.61753704,  29.91734969],
#        [  3.36016479,  29.57124212,  52.69365125, -21.99253075],
#        [  4.26152071,  -7.44687007, -16.61824695,  62.74121513]],
#          alphabet='GCTA'), 'Gap opens': np.float64(55.62716179730383), 'Gap extends': np.float64(-345.89213212889433)}
# Stepsize: 5e-05
# Gap open step: 0.0027813580898651915
# Gap extend step: -0.017294606606444718
# New parameters:
# {'alpha': np.float64(-10.815438561675338), 'substitution_matrix': Array([[ 1.18202029, -0.84124278, -0.76803959, -0.56121667],
#        [-0.76344777,  1.09783801, -0.55106606, -0.60042216],
#        [-0.76394983, -0.43171282,  0.9149887 , -0.88386647],
#        [-0.67793538, -0.25612905, -0.69925146,  0.89671877]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1306296252415489), 'extend_gap_score': np.float64(-0.0888061799171586)}
# Subgradient norm: 376.42229323518666
# End of iteration 9
#
# Start of iteration 10
# Current alpha: -10.815438561675338
# Current logL: -2963.8844168941673
# Updated alpha: -10.730032257818138
# Updated logL: -2960.1995756590286
# New subgradient:
# {'Substitutions': Array([[ 7.68204447e+01, -3.40084543e+01, -1.42595800e+01,
#          2.71251051e+01],
#        [-1.42886467e+01,  8.01341187e+01,  1.97634800e+01,
#          2.55168531e+01],
#        [-3.33423593e-02,  1.75536339e+01,  8.76453035e+01,
#         -2.37474115e+01],
#        [ 2.70454903e+00, -2.58618345e+00, -2.05999207e+01,
#          6.24624729e+01]],
#          alphabet='GCTA'), 'Gap opens': np.float64(107.50794734587657), 'Gap extends': np.float64(281.8681231594431)}
# Stepsize: 5e-05
# Gap open step: 0.005375397367293829
# Gap extend step: 0.014093406157972155
# New parameters:
# {'alpha': np.float64(-10.730032257818138), 'substitution_matrix': Array([[ 1.18586129, -0.8429432 , -0.76875257, -0.55986038],
#        [-0.76416217,  1.10184471, -0.5500778 , -0.59914638],
#        [-0.76395145, -0.43083522,  0.91937095, -0.88505384],
#        [-0.67780016, -0.25625832, -0.70028144,  0.89984195]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1256338523448157), 'extend_gap_score': np.float64(-0.07428459725909609)}
# Subgradient norm: 345.78265064977353
# End of iteration 10
#
# Start of iteration 11
# Current alpha: -10.730032257818138
# Current logL: -2980.8535438625368
# Updated alpha: -10.938778342180946
# Updated logL: -2958.6350842942893
# New subgradient:
# {'Substitutions': Array([[ 52.95572951, -28.98951123, -11.86426545,  26.97673603],
#        [-14.04863953,  64.48028826,  12.61665291,  27.56035545],
#        [  4.5881223 ,  28.32307759,  40.21481122, -21.042707  ],
#        [  4.52913895,  -7.16582983, -16.62403532,  48.26660936]],
#          alphabet='GCTA'), 'Gap opens': np.float64(31.921019448835757), 'Gap extends': np.float64(-286.5187525347386)}
# Stepsize: 5e-05
# Gap open step: 0.001596050972441788
# Gap extend step: -0.014325937626736932
# New parameters:
# {'alpha': np.float64(-10.938778342180946), 'substitution_matrix': Array([[ 1.18850906, -0.84439268, -0.76934586, -0.55851161],
#        [-0.76486462,  1.10506869, -0.54944693, -0.59776838],
#        [-0.76372209, -0.42941912,  0.92138169, -0.88610593],
#        [-0.67757376, -0.25661659, -0.70111265,  0.90225533]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1232284586039), 'extend_gap_score': np.float64(-0.08945403401740011)}
# Subgradient norm: 313.78331232559464
# End of iteration 11
#
# Start of iteration 12
# Current alpha: -10.938778342180946
# Current logL: -2960.8750977735053
# Updated alpha: -10.855921383355401
# Updated logL: -2957.4167390545526
# New subgradient:
# {'Substitutions': Array([[ 70.73627488, -32.84713638, -13.77839262,  24.75943277],
#        [-15.3766304 ,  62.60558777,  21.15647559,  26.38785376],
#        [  0.08805923,  20.52834713,  73.34852184, -23.78127161],
#        [  5.87139855,  -2.30491048, -19.8346988 ,  58.16267606]],
#          alphabet='GCTA'), 'Gap opens': np.float64(76.461010114339), 'Gap extends': np.float64(223.84132332517166)}
# Stepsize: 5e-05
# Gap open step: 0.0038230505057169502
# Gap extend step: 0.011192066166258584
# New parameters:
# {'alpha': np.float64(-10.855921383355401), 'substitution_matrix': Array([[ 1.19204584, -0.846035  , -0.77003476, -0.55727366],
#        [-0.76563346,  1.10819895, -0.54838911, -0.59644897],
#        [-0.76371768, -0.42839272,  0.92504911, -0.88729496],
#        [-0.67728021, -0.25673184, -0.7021044 ,  0.90516351]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.118671305087936), 'extend_gap_score': np.float64(-0.07975782018706709)}
# Subgradient norm: 279.8560766878531
# End of iteration 12
#
# Start of iteration 13
# Current alpha: -10.855921383355401
# Current logL: -2967.7761140185735
# Updated alpha: -11.011190855121551
# Updated logL: -2955.549659754314
# New subgradient:
# {'Substitutions': Array([[ 47.36273525, -29.45930433, -15.24011127,  30.13008189],
#        [-13.22741685,  56.08280609,  12.21511914,  24.98800061],
#        [  5.46939958,  25.81187611,  33.68709728, -20.36403348],
#        [  2.14611036,  -5.29517234, -16.37688501,  44.45810973]],
#          alphabet='GCTA'), 'Gap opens': np.float64(17.13816951882171), 'Gap extends': np.float64(-186.05372168290282)}
# Stepsize: 5e-05
# Gap open step: 0.0008569084759410855
# Gap extend step: -0.009302686084145141
# New parameters:
# {'alpha': np.float64(-11.011190855121551), 'substitution_matrix': Array([[ 1.19441395, -0.84750796, -0.77079677, -0.55576712],
#        [-0.76629484,  1.11100308, -0.54777836, -0.59519959],
#        [-0.76344427, -0.42710213,  0.92673347, -0.88831313],
#        [-0.6771729 , -0.25699665, -0.70292322,  0.90738639]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1182603056803755), 'extend_gap_score': np.float64(-0.08852919098917862)}
# Subgradient norm: 218.58089380964336
# End of iteration 13
#
# Start of iteration 14
# Current alpha: -11.011190855121551
# Current logL: -2955.8454329271653
# Updated alpha: -10.973298901315486
# Updated logL: -2955.122998067609
# New subgradient:
# {'Substitutions': Array([[ 61.03733685, -32.5463345 , -15.78902123,  28.68005133],
#        [-13.80427557,  47.32621839,  15.1797516 ,  25.77490252],
#        [ -0.77117595,  19.2610964 ,  66.68205047, -24.85314127],
#        [  6.45972957,  -1.33756192, -20.1586672 ,  53.85462771]],
#          alphabet='GCTA'), 'Gap opens': np.float64(52.43701576876039), 'Gap extends': np.float64(202.297944572478)}
# Stepsize: 5e-05
# Gap open step: 0.0026218507884380195
# Gap extend step: 0.0101148972286239
# New parameters:
# {'alpha': np.float64(-10.973298901315486), 'substitution_matrix': Array([[ 1.19746579, -0.84913529, -0.77158618, -0.5543331 ],
#        [-0.76698502,  1.11336938, -0.5470194 , -0.59391081],
#        [-0.76348283, -0.42613905,  0.93006759, -0.88955579],
#        [-0.67684991, -0.25706348, -0.70393118,  0.91007913]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1163180589883621), 'extend_gap_score': np.float64(-0.07757358075703094)}
# Subgradient norm: 248.2778561524598
# End of iteration 14
#
# Start of iteration 15
# Current alpha: -10.973298901315486
# Current logL: -2966.317224851327
# Updated alpha: -11.124388614163175
# Updated logL: -2954.756856332359
# New subgradient:
# {'Substitutions': Array([[ 42.65158494, -29.23788187, -14.0882381 ,  28.36865025],
#        [-13.67596279,  49.32814024,  12.2368255 ,  23.65028791],
#        [  5.54343813,  24.88956403,  22.43848838, -21.51396439],
#        [  3.62392259,  -7.97490974, -17.60421286,  36.70672998]],
#          alphabet='GCTA'), 'Gap opens': np.float64(2.60336635588608), 'Gap extends': np.float64(-278.34647288149796)}
# Stepsize: 5e-05
# Gap open step: 0.000130168317794304
# Gap extend step: -0.013917323644074898
# New parameters:
# {'alpha': np.float64(-11.124388614163175), 'substitution_matrix': Array([[ 1.19959845, -0.85059719, -0.77229061, -0.55291465],
#        [-0.76766877,  1.11583582, -0.54640755, -0.59272827],
#        [-0.76320568, -0.42489455,  0.93118952, -0.89063148],
#        [-0.67666871, -0.25746223, -0.70481143,  0.9119144 ]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1168840420281008), 'extend_gap_score': np.float64(-0.09114525163954482)}
# Subgradient norm: 296.3796914399254
# End of iteration 15
#
# Start of iteration 16
# Current alpha: -11.124388614163175
# Current logL: -2958.1320577804463
# Updated alpha: -11.034248908054469
# Updated logL: -2954.0608172330817
# New subgradient:
# {'Substitutions': Array([[ 5.64124270e+01, -3.22486666e+01, -1.64612367e+01,
#          2.64276110e+01],
#        [-1.60598733e+01,  4.36543090e+01,  1.97358828e+01,
#          2.31611192e+01],
#        [-1.53663513e-03,  1.69641251e+01,  6.09307230e+01,
#         -2.53378900e+01],
#        [ 6.22246099e+00,  6.83622949e-02, -2.01304864e+01,
#          5.05321407e+01]],
#          alphabet='GCTA'), 'Gap opens': np.float64(46.74324217568061), 'Gap extends': np.float64(205.27139319841908)}
# Stepsize: 5e-05
# Gap open step: 0.0023371621087840302
# Gap extend step: 0.010263569659920955
# New parameters:
# {'alpha': np.float64(-11.034248908054469), 'substitution_matrix': Array([[ 1.20241906, -0.85220958, -0.77311366, -0.55159331],
#        [-0.76847176,  1.11801855, -0.54542077, -0.59157023],
#        [-0.76320573, -0.42404639,  0.93423608, -0.89189838],
#        [-0.67635758, -0.25745882, -0.70581802,  0.914441  ]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1135849419521484), 'extend_gap_score': np.float64(-0.08115806707612147)}
# Subgradient norm: 245.4431246991482
# End of iteration 16
#
# Start of iteration 17
# Current alpha: -11.034248908054469
# Current logL: -2963.0051552946115
# Updated alpha: -11.177001639598137
# Updated logL: -2952.7218984052147
# New subgradient:
# {'Substitutions': Array([[ 35.14790151, -28.52262365, -14.06808698,  27.88368573],
#        [-12.60290863,  53.86763591,   9.03559081,  22.71264528],
#        [  4.06480002,  24.54642446,  24.70480797, -22.28507236],
#        [  4.15240503,  -4.64511518, -13.80122718,  35.98441573]],
#          alphabet='GCTA'), 'Gap opens': np.float64(5.501544102742754), 'Gap extends': np.float64(-231.85333840969875)}
# Stepsize: 5e-05
# Gap open step: 0.00027507720513713773
# Gap extend step: -0.011592666920484938
# New parameters:
# {'alpha': np.float64(-11.177001639598137), 'substitution_matrix': Array([[ 1.20417646, -0.85363571, -0.77381709, -0.5501991 ],
#        [-0.76910188,  1.1207119 , -0.54496901, -0.59043459],
#        [-0.76300248, -0.42281911,  0.93547136, -0.89301267],
#        [-0.67614997, -0.25769106, -0.70650814,  0.91624019]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1130596037897393), 'extend_gap_score': np.float64(-0.09255541765581593)}
# Subgradient norm: 252.4257861623247
# End of iteration 17
#
# Start of iteration 18
# Current alpha: -11.177001639598137
# Current logL: -2955.0078840766437
# Updated alpha: -11.110528287606128
# Updated logL: -2952.797994185888
# New subgradient:
# {'Substitutions': Array([[ 57.14135436, -33.43683463, -16.03624148,  26.662726  ],
#        [-16.0031559 ,  43.50208717,  19.94582618,  23.53601747],
#        [ -0.13309208,  16.98680848,  62.19683566, -27.02336173],
#        [  5.94516691,   1.2794247 , -19.93329251,  48.30397731]],
#          alphabet='GCTA'), 'Gap opens': np.float64(50.30676493085697), 'Gap extends': np.float64(251.1299265440428)}
# Stepsize: 5e-05
# Gap open step: 0.002515338246542849
# Gap extend step: 0.01255649632720214
# New parameters:
# {'alpha': np.float64(-11.110528287606128), 'substitution_matrix': Array([[ 1.20703353, -0.85530757, -0.77461886, -0.54886595],
#        [-0.76990204,  1.12288704, -0.54397171, -0.58925782],
#        [-0.7630092 , -0.4219698 ,  0.93858118, -0.89436382],
#        [-0.67585272, -0.25762714, -0.70750485,  0.9186554 ]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.110850610057365), 'extend_gap_score': np.float64(-0.07929813302065752)}
# Subgradient norm: 285.83813240000126
# End of iteration 18
#
# Start of iteration 19
# Current alpha: -11.110528287606128
# Current logL: -2966.4794785459076
# Updated alpha: -11.279015494167467
# Updated logL: -2952.165644480687
# New subgradient:
# {'Substitutions': Array([[ 32.17251262, -29.27701445, -14.69752647,  27.31897163],
#        [-12.78192322,  43.94447128,  11.37555541,  22.3847055 ],
#        [  4.09761711,  23.11630392,  18.15359071, -20.00489706],
#        [  4.04206128,  -4.98113123, -15.85889326,  29.77291493]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-11.348408337237034), 'Gap extends': np.float64(-280.93288064573466)}
# Stepsize: 5e-05
# Gap open step: -0.0005674204168618517
# Gap extend step: -0.014046644032286733
# New parameters:
# {'alpha': np.float64(-11.279015494167467), 'substitution_matrix': Array([[ 1.20864218, -0.85677143, -0.77535371, -0.54750001],
#        [-0.77054113,  1.12508428, -0.54340293, -0.5881386 ],
#        [-0.76280434, -0.420814  ,  0.93948886, -0.89536411],
#        [-0.67565063, -0.25787617, -0.70829779,  0.92014409]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1118660674820484), 'extend_gap_score': np.float64(-0.09272717891203011)}
# Subgradient norm: 295.11297207311776
# End of iteration 19
#
# Start of iteration 20
# Current alpha: -11.279015494167467
# Current logL: -2956.1295275402745
# Updated alpha: -11.182807452554847
# Updated logL: -2951.5122739089456
# New subgradient:
# {'Substitutions': Array([[ 51.20441403, -33.38251991, -16.22912528,  29.31631332],
#        [-14.76059759,  41.00428519,  23.05325949,  21.75348005],
#        [  0.35808845,  16.66319457,  57.08102714, -25.40707778],
#        [  6.29744875,   3.05612773, -19.61739796,  46.52561872]],
#          alphabet='GCTA'), 'Gap opens': np.float64(36.69468757272901), 'Gap extends': np.float64(240.06390313245404)}
# Stepsize: 5e-05
# Gap open step: 0.0018347343786364505
# Gap extend step: 0.012003195156622702
# New parameters:
# {'alpha': np.float64(-11.182807452554847), 'substitution_matrix': Array([[ 1.21120235, -0.85844059, -0.77616515, -0.54603422],
#        [-0.77127915,  1.12713448, -0.54225025, -0.58705089],
#        [-0.76278644, -0.41998082,  0.94234293, -0.89663445],
#        [-0.67533573, -0.25772334, -0.70927867,  0.92247038]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.110567200704929), 'extend_gap_score': np.float64(-0.08064952372946939)}
# Subgradient norm: 271.1460682646521
# End of iteration 20
#
# Start of iteration 21
# Current alpha: -11.182807452554847
# Current logL: -2962.436204055467
# Updated alpha: -11.334221060378
# Updated logL: -2950.9074337190177
# New subgradient:
# {'Substitutions': Array([[ 30.63712975, -31.89685723, -14.57654352,  26.89910983],
#        [-13.49110665,  39.09271005,  14.83505533,  20.19820366],
#        [  3.81297406,  23.58221081,  14.38817217, -19.65041902],
#        [  3.4473486 ,  -5.652396  , -17.75498126,  31.55215994]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-10.58055779593144), 'Gap extends': np.float64(-257.8596269677971)}
# Stepsize: 5e-05
# Gap open step: -0.0005290278897965721
# Gap extend step: -0.012892981348389856
# New parameters:
# {'alpha': np.float64(-11.334221060378), 'substitution_matrix': Array([[ 1.21273421, -0.86003542, -0.77689396, -0.54468924],
#        [-0.7719537 ,  1.12908911, -0.54150848, -0.58604096],
#        [-0.76259579, -0.41880171,  0.9430623 , -0.89761701],
#        [-0.67516334, -0.25800597, -0.71016641,  0.92404801]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1112462454781877), 'extend_gap_score': np.float64(-0.09381655812581771)}
# Subgradient norm: 272.67636324553234
# End of iteration 21
#
# Start of iteration 22
# Current alpha: -11.334221060378
# Current logL: -2954.9525933150276
# Updated alpha: -11.240228171223372
# Updated logL: -2950.5548625671227
# New subgradient:
# {'Substitutions': Array([[ 50.40956129, -32.93088008, -16.23852185,  27.4709209 ],
#        [-14.92837399,  36.00481027,  26.31821084,  24.27190828],
#        [  0.68121439,  15.65030747,  54.33454462, -25.39971683],
#        [  5.25286832,   1.8919371 , -18.86276499,  41.32896054]],
#          alphabet='GCTA'), 'Gap opens': np.float64(28.266248673040725), 'Gap extends': np.float64(237.56248604012123)}
# Stepsize: 5e-05
# Gap open step: 0.0014133124336520363
# Gap extend step: 0.011878124302006063
# New parameters:
# {'alpha': np.float64(-11.240228171223372), 'substitution_matrix': Array([[ 1.21525468, -0.86168195, -0.77770584, -0.54331573],
#        [-0.77270011,  1.13088933, -0.54019258, -0.58482735],
#        [-0.76256172, -0.41801917,  0.94577906, -0.89888697],
#        [-0.67490073, -0.25791134, -0.71110953,  0.92611445]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1103594001479125), 'extend_gap_score': np.float64(-0.08227921218322864)}
# Subgradient norm: 265.739576080193
# End of iteration 22
#
# Start of iteration 23
# Current alpha: -11.240228171223372
# Current logL: -2959.7617804558668
# Updated alpha: -11.382259766171186
# Updated logL: -2949.6431606917354
# New subgradient:
# {'Substitutions': Array([[ 25.21623916, -28.72071547, -11.70044974,  26.26522944],
#        [-14.63203092,  37.71472072,  14.99455418,  21.07321963],
#        [  3.48333971,  23.67340413,  13.68898691, -18.84687175],
#        [  2.90841149,  -1.59837308, -17.70797725,  29.39292404]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-18.482593042915433), 'Gap extends': np.float64(-267.24488667006796)}
# Stepsize: 5e-05
# Gap open step: -0.0009241296521457717
# Gap extend step: -0.013362244333503399
# New parameters:
# {'alpha': np.float64(-11.382259766171186), 'substitution_matrix': Array([[ 1.21651549, -0.863118  , -0.77829085, -0.54200248],
#        [-0.77343169,  1.1327751 , -0.53944288, -0.58377368],
#        [-0.76238753, -0.41683549,  0.94646353, -0.89982929],
#        [-0.67475532, -0.25799124, -0.71199492,  0.92758408]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1114549934324771), 'extend_gap_score': np.float64(-0.09614185056657734)}
# Subgradient norm: 280.4604120758446
# End of iteration 23
#
# Start of iteration 24
# Current alpha: -11.382259766171186
# Current logL: -2955.2949780066615
# Updated alpha: -11.279682735741437
# Updated logL: -2950.0712156000236
# New subgradient:
# {'Substitutions': Array([[ 44.22241916, -30.24773788, -13.82028611,  23.84896638],
#        [-14.48237919,  38.73400168,  26.11093537,  20.46522489],
#        [  1.25055666,  13.70366019,  49.14671033, -24.08646273],
#        [  4.33494062,   1.81564776, -19.59645944,  47.04393711]],
#          alphabet='GCTA'), 'Gap opens': np.float64(29.521712894188518), 'Gap extends': np.float64(256.3630755579786)}
# Stepsize: 5e-05
# Gap open step: 0.001476085644709426
# Gap extend step: 0.012818153777898932
# New parameters:
# {'alpha': np.float64(-11.279682735741437), 'substitution_matrix': Array([[ 1.21872664, -0.86463041, -0.77898181, -0.54081   ],
#        [-0.77415582,  1.13471177, -0.53813732, -0.58275042],
#        [-0.76232499, -0.4161503 ,  0.94892088, -0.90103361],
#        [-0.67453856, -0.25790047, -0.71297475,  0.92993629]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1101553218392082), 'extend_gap_score': np.float64(-0.0826795914050094)}
# Subgradient norm: 280.7825635317829
# End of iteration 24
#
# Start of iteration 25
# Current alpha: -11.279682735741437
# Current logL: -2961.369693158659
# Updated alpha: -11.43819557137194
# Updated logL: -2948.7855723578746
# New subgradient:
# {'Substitutions': Array([[ 28.59381891, -30.96333695, -11.53090016,  26.40685683],
#        [-14.71861019,  32.60344888,  15.45306408,  20.73258748],
#        [  5.14957984,  22.03058725,   9.15223301, -18.81613529],
#        [  2.85994877,  -1.33040754, -17.03329504,  28.25934737]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-22.47579489677431), 'Gap extends': np.float64(-230.55128547915797)}
# Stepsize: 5e-05
# Gap open step: -0.0011237897448387155
# Gap extend step: -0.011527564273957899
# New parameters:
# {'alpha': np.float64(-11.43819557137194), 'substitution_matrix': Array([[ 1.22015635, -0.86617858, -0.77955835, -0.53948966],
#        [-0.77489174,  1.13634196, -0.53736463, -0.58171377],
#        [-0.76206754, -0.41504877,  0.9493785 , -0.90197441],
#        [-0.67439558, -0.25796701, -0.71382645,  0.93134928]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1111766737186994), 'extend_gap_score': np.float64(-0.09469327621481002)}
# Subgradient norm: 245.48396963221856
# End of iteration 25
#
# Start of iteration 26
# Current alpha: -11.43819557137194
# Current logL: -2952.56124395821
# Updated alpha: -11.35014066589031
# Updated logL: -2948.7150098893085
# New subgradient:
# {'Substitutions': Array([[ 43.95445068, -29.31874795, -15.21100474,  23.71792203],
#        [-14.41375775,  30.1048695 ,  25.05010689,  20.87467709],
#        [  1.3243309 ,  13.06391768,  45.55760326, -22.63728574],
#        [  3.97847706,   3.52671008, -18.63795287,  44.00148272]],
#          alphabet='GCTA'), 'Gap opens': np.float64(18.06104185255942), 'Gap extends': np.float64(239.17537253815948)}
# Stepsize: 5e-05
# Gap open step: 0.000903052092627971
# Gap extend step: 0.011958768626907975
# New parameters:
# {'alpha': np.float64(-11.35014066589031), 'substitution_matrix': Array([[ 1.22235411, -0.8676445 , -0.78031892, -0.53830373],
#        [-0.77561245,  1.13784722, -0.53611212, -0.58067003],
#        [-0.76200135, -0.41439558,  0.95165639, -0.90310628],
#        [-0.67419666, -0.25779064, -0.71475833,  0.93354936]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1104961380244396), 'extend_gap_score': np.float64(-0.08263083868895194)}
# Subgradient norm: 261.469243672143
# End of iteration 26
#
# Start of iteration 27
# Current alpha: -11.35014066589031
# Current logL: -2958.1419302681525
# Updated alpha: -11.491969018752664
# Updated logL: -2948.0853780505818
# New subgradient:
# {'Substitutions': Array([[ 23.42934985, -30.9842506 , -12.83278027,  30.69619487],
#        [-14.61645217,  34.05211998,  16.95902743,  18.19196502],
#        [  5.14325629,  23.62643078,   3.95052352, -17.62118591],
#        [  2.71351622,   0.37710914, -17.65471528,  26.18035814]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-29.146269381225622), 'Gap extends': np.float64(-256.2578148706094)}
# Stepsize: 5e-05
# Gap open step: -0.0014573134690612811
# Gap extend step: -0.012812890743530472
# New parameters:
# {'alpha': np.float64(-11.491969018752664), 'substitution_matrix': Array([[ 1.22352557, -0.86919372, -0.78096055, -0.53676888],
#        [-0.77634327,  1.13954981, -0.53526415, -0.57976046],
#        [-0.76174416, -0.41321424,  0.95185392, -0.90398736],
#        [-0.674061  , -0.25777178, -0.71564108,  0.93485837]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.111543614786248), 'extend_gap_score': np.float64(-0.09489257608759293)}
# Subgradient norm: 270.2603184460945
# End of iteration 27
#
# Start of iteration 28
# Current alpha: -11.491969018752664
# Current logL: -2952.1377833546944
# Updated alpha: -11.399179049370334
# Updated logL: -2947.8738746289764
# New subgradient:
# {'Substitutions': Array([[ 43.39708809, -29.81968314, -15.72540408,  24.47227839],
#        [-14.31328874,  28.85267151,  24.38214097,  18.9943713 ],
#        [  1.68347612,  14.18400711,  40.52409906, -20.58740484],
#        [  4.68104063,   5.61199698, -18.46326974,  40.8303173 ]],
#          alphabet='GCTA'), 'Gap opens': np.float64(13.344906705628558), 'Gap extends': np.float64(217.77983851375984)}
# Stepsize: 5e-05
# Gap open step: 0.000667245335281428
# Gap extend step: 0.010888991925687992
# New parameters:
# {'alpha': np.float64(-11.399179049370334), 'substitution_matrix': Array([[ 1.22569542, -0.87068469, -0.78174681, -0.53554526],
#        [-0.77705895,  1.14099248, -0.53404508, -0.57881078],
#        [-0.76165998, -0.41250505,  0.95388014, -0.90501675],
#        [-0.67382692, -0.25749118, -0.71656423,  0.93689988]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.110904715335059), 'extend_gap_score': np.float64(-0.08398411218798486)}
# Subgradient norm: 239.89358521262102
# End of iteration 28
#
# Start of iteration 29
# Current alpha: -11.399179049370334
# Current logL: -2955.440473046586
# Updated alpha: -11.528666596549533
# Updated logL: -2947.0764450929682
# New subgradient:
# {'Substitutions': Array([[ 20.68136014, -29.76426789, -13.36712354,  29.70332282],
#        [-14.69549621,  34.01245312,  18.16924504,  17.59850144],
#        [  4.23140884,  21.58453161,   8.44032984, -17.65970852],
#        [  3.72668465,   0.82641766, -17.74603129,  23.90178186]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-29.50229765986123), 'Gap extends': np.float64(-192.4970097246716)}
# Stepsize: 5e-05
# Gap open step: -0.0014751148829930617
# Gap extend step: -0.009624850486233582
# New parameters:
# {'alpha': np.float64(-11.528666596549533), 'substitution_matrix': Array([[ 1.22672949, -0.87217292, -0.78241516, -0.53406009],
#        [-0.77779371,  1.14269309, -0.5331366 , -0.57793086],
#        [-0.76144841, -0.41142583,  0.95430214, -0.90589972],
#        [-0.67364057, -0.25744985, -0.71745153,  0.93809497]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1130173482427579), 'extend_gap_score': np.float64(-0.09347669785165523)}
# Subgradient norm: 209.95329044600314
# End of iteration 29
#
# Start of iteration 30
# Current alpha: -11.528666596549533
# Current logL: -2949.395533897468
# Updated alpha: -11.455748092332962
# Updated logL: -2946.7640991184785
# New subgradient:
# {'Substitutions': Array([[ 45.49410423, -31.30668226, -16.24934466,  22.52998645],
#        [-12.48013101,  20.52522305,  22.0232019 ,  19.22034738],
#        [  0.84046981,  13.55275905,  36.73775847, -21.14152957],
#        [  3.70730082,   4.07865736, -16.51396312,  33.02738827]],
#          alphabet='GCTA'), 'Gap opens': np.float64(6.207263739733513), 'Gap extends': np.float64(181.93262977094813)}
# Stepsize: 5e-05
# Gap open step: 0.0003103631869866757
# Gap extend step: 0.009096631488547407
# New parameters:
# {'alpha': np.float64(-11.455748092332962), 'substitution_matrix': Array([[ 1.22900422, -0.87373825, -0.78322764, -0.53293362],
#        [-0.77841773,  1.14371932, -0.53203547, -0.57696986],
#        [-0.76140639, -0.4107482 ,  0.95613902, -0.90695683],
#        [-0.67345521, -0.2572459 , -0.71827722,  0.93974632]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1130435621858084), 'extend_gap_score': np.float64(-0.08446867656642001)}
# Subgradient norm: 204.36686925856182
# End of iteration 30
#
# Start of iteration 31
# Current alpha: -11.455748092332962
# Current logL: -2952.0752882511583
# Updated alpha: -11.563306424992728
# Updated logL: -2946.316334377908
# New subgradient:
# {'Substitutions': Array([[ 16.47419015, -29.20524225, -13.4261254 ,  27.67414003],
#        [-14.81829586,  33.04003543,  18.73693697,  17.19461724],
#        [  4.32660968,  17.89145339,  11.22146629, -17.75595891],
#        [  2.61102294,   2.43771762, -18.19269443,  21.02743438]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-31.12879193305939), 'Gap extends': np.float64(-153.93410460681045)}
# Stepsize: 5e-05
# Gap open step: -0.0015564395966529696
# Gap extend step: -0.0076967052303405226
# New parameters:
# {'alpha': np.float64(-11.563306424992728), 'substitution_matrix': Array([[ 1.22982791, -0.87519852, -0.78389894, -0.53154992],
#        [-0.77915868,  1.14537131, -0.53109862, -0.57611011],
#        [-0.76119007, -0.40985364,  0.95670011, -0.90784459],
#        [-0.67332468, -0.257124  , -0.71918686,  0.9407977 ]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.11420409838565), 'extend_gap_score': np.float64(-0.0914517504240499)}
# Subgradient norm: 173.95122227458182
# End of iteration 31
#
# Start of iteration 32
# Current alpha: -11.563306424992728
# Current logL: -2946.968041414041
# Updated alpha: -11.514361455626274
# Updated logL: -2945.7826985023594
# New subgradient:
# {'Substitutions': Array([[ 38.82266406, -31.09715464, -17.1902497 ,  22.29071243],
#        [-11.95814133,  21.03121218,  20.37559323,  18.95973175],
#        [  2.06444901,  15.21321531,  26.72657621, -21.52461271],
#        [  5.22830309,   2.28649415, -16.00797192,  28.41049615]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-5.1356064946837225), 'Gap extends': np.float64(97.69661131715743)}
# Stepsize: 5e-05
# Gap open step: -0.0002567803247341861
# Gap extend step: 0.004884830565857872
# New parameters:
# {'alpha': np.float64(-11.514361455626274), 'substitution_matrix': Array([[ 1.23176906, -0.87675337, -0.78475847, -0.53043539],
#        [-0.77975657,  1.14642288, -0.53007984, -0.57516211],
#        [-0.76108685, -0.40909299,  0.95803643, -0.90892083],
#        [-0.67306325, -0.25700966, -0.71998724,  0.9422182 ]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.114665456022597), 'extend_gap_score': np.float64(-0.08666670127592047)}
# Subgradient norm: 129.25486346639556
# End of iteration 32
#
# Start of iteration 33
# Current alpha: -11.514361455626274
# Current logL: -2947.5503597304205
# Updated alpha: -11.578995312570708
# Updated logL: -2945.476862523636
# New subgradient:
# {'Substitutions': Array([[ 15.73841633, -25.76730608, -14.46733041,  23.49310423],
#        [-13.30968267,  30.41267736,  19.67039763,  15.46635334],
#        [  3.7771453 ,  17.18642755,  18.53951947, -18.41122108],
#        [  3.6844163 ,   3.31122759, -17.19134727,  27.88880472]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-24.659181512249162), 'Gap extends': np.float64(-65.89755887274531)}
# Stepsize: 5e-05
# Gap open step: -0.0012329590756124582
# Gap extend step: -0.0032948779436372654
# New parameters:
# {'alpha': np.float64(-11.578995312570708), 'substitution_matrix': Array([[ 1.23255599, -0.87804175, -0.78548184, -0.52926074],
#        [-0.78042209,  1.14794349, -0.52909632, -0.5743888 ],
#        [-0.76089803, -0.40823365,  0.9589634 , -0.9098414 ],
#        [-0.67287903, -0.2568441 , -0.72084682,  0.94361265]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.115827159414235), 'extend_gap_score': np.float64(-0.09020143010995638)}
# Subgradient norm: 102.18545761406402
# End of iteration 33
#
# Start of iteration 34
# Current alpha: -11.578995312570708
# Current logL: -2945.209167970957
# Updated alpha: -11.562232160994492
# Updated logL: -2945.070164666919
# New subgradient:
# {'Substitutions': Array([[ 32.1003479 , -28.06797225, -16.38628142,  21.66910353],
#        [-12.20745566,  21.80086848,  21.94838225,  17.00539574],
#        [  3.05712419,  14.47758318,  22.09861191, -20.70437452],
#        [  4.49148451,   1.74323285, -15.23551349,  27.22261705]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-11.33478070464839), 'Gap extends': np.float64(19.093917001766194)}
# Stepsize: 5e-05
# Gap open step: -0.0005667390352324195
# Gap extend step: 0.0009546958500883097
# New parameters:
# {'alpha': np.float64(-11.562232160994492), 'substitution_matrix': Array([[ 1.23416103, -0.87944513, -0.78630116, -0.52817725],
#        [-0.78103246,  1.14903355, -0.52799889, -0.57353852],
#        [-0.76074517, -0.40750978,  0.96006834, -0.91087662],
#        [-0.67265446, -0.25675694, -0.72160858,  0.94497377]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1163394646386924), 'extend_gap_score': np.float64(-0.0892416687942744)}
# Subgradient norm: 81.09877980504066
# End of iteration 34
#
# Start of iteration 35
# Current alpha: -11.562232160994492
# Current logL: -2945.1692915064314
# Updated alpha: -11.590460123381806
# Updated logL: -2944.774924207906
# New subgradient:
# {'Substitutions': Array([[ 24.75397913, -26.52543083, -15.58607686,  20.17693317],
#        [-11.94423876,  25.96979743,  20.91139951,  17.53169398],
#        [  3.44699846,  14.60157492,  19.55671944, -19.86624059],
#        [  4.12893805,   3.15745428, -15.75511447,  24.44788769]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-17.269438538499962), 'Gap extends': np.float64(-27.276021442700078)}
# Stepsize: 5e-05
# Gap open step: -0.0008634719269249981
# Gap extend step: -0.001363801072135004
# New parameters:
# {'alpha': np.float64(-11.590460123381806), 'substitution_matrix': Array([[ 1.23539873, -0.88077142, -0.78708047, -0.5271684 ],
#        [-0.78162968,  1.15033205, -0.52695333, -0.57266191],
#        [-0.7605728 , -0.40677969,  0.96104618, -0.9118699 ],
#        [-0.67244803, -0.25659906, -0.72239634,  0.94619617]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1172101565996364), 'extend_gap_score': np.float64(-0.09053283154245789)}
# Subgradient norm: 80.28424469735862
# End of iteration 35
#
# Start of iteration 36
# Current alpha: -11.590460123381806
# Current logL: -2944.4936892217133
# Updated alpha: -11.595688926504364
# Updated logL: -2944.4801783727753
# New subgradient:
# {'Substitutions': Array([[ 28.76430145, -26.7359709 , -15.46496184,  19.7450782 ],
#        [-12.19827028,  21.98562915,  20.1383418 ,  20.02869771],
#        [  2.89650811,  13.94910906,  23.67001096, -20.64696023],
#        [  4.31306641,   1.31086564, -15.79082992,  26.11688691]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-11.617049636088533), 'Gap extends': np.float64(20.127952233231213)}
# Stepsize: 5e-05
# Gap open step: -0.0005808524818044266
# Gap extend step: 0.0010063976116615606
# New parameters:
# {'alpha': np.float64(-11.595688926504364), 'substitution_matrix': Array([[ 1.23683694, -0.88210821, -0.78785371, -0.52618115],
#        [-0.78223958,  1.15143135, -0.52594641, -0.57166048],
#        [-0.76042797, -0.40608223,  0.96222967, -0.91290225],
#        [-0.67223239, -0.25653352, -0.72318588,  0.94750202]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1176359167448568), 'extend_gap_score': np.float64(-0.08911925850160948)}
# Subgradient norm: 79.3188172141433
# End of iteration 36
#
# Start of iteration 37
# Current alpha: -11.595688926504364
# Current logL: -2944.7161651136807
# Updated alpha: -11.627508367319368
# Updated logL: -2944.2156228761264
# New subgradient:
# {'Substitutions': Array([[ 20.99301665, -25.55944198, -15.15591916,  20.01691697],
#        [-11.89368299,  27.20693211,  19.4725187 ,  17.58204003],
#        [  3.87262008,  15.90268005,  20.38194294, -18.90240614],
#        [  3.63413473,   3.00295061, -15.08089444,  23.17224212]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-19.670566918794165), 'Gap extends': np.float64(-25.674891463248702)}
# Stepsize: 5e-05
# Gap open step: -0.0009835283459397083
# Gap extend step: -0.0012837445731624351
# New parameters:
# {'alpha': np.float64(-11.627508367319368), 'substitution_matrix': Array([[ 1.23788657, -0.88338617, -0.7886115 , -0.52518029],
#        [-0.78283426,  1.15279168, -0.52497278, -0.57078136],
#        [-0.76023434, -0.4052871 ,  0.96324878, -0.9138474 ],
#        [-0.67205068, -0.25638338, -0.72393992,  0.94866063]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1188982575215782), 'extend_gap_score': np.float64(-0.09058671630210263)}
# Subgradient norm: 78.53474565318778
# End of iteration 37
#
# Start of iteration 38
# Current alpha: -11.627508367319368
# Current logL: -2943.914455910065
# Updated alpha: -11.628954382475657
# Updated logL: -2943.9134239835284
# New subgradient:
# {'Substitutions': Array([[ 28.63221411, -26.36977887, -14.33709183,  19.77632638],
#        [-12.32374041,  20.52789346,  19.87295535,  18.69788787],
#        [  2.7630351 ,  13.58714057,  22.12399676, -19.91840386],
#        [  4.10446343,   2.17144006, -16.17469885,  23.34117768]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-12.679717988374057), 'Gap extends': np.float64(-1.2886256600535528)}
# Stepsize: 5e-05
# Gap open step: -0.0006339858994187028
# Gap extend step: -6.443128300267764e-05
# New parameters:
# {'alpha': np.float64(-11.628954382475657), 'substitution_matrix': Array([[ 1.23931816, -0.88470465, -0.78932835, -0.5241915 ],
#        [-0.78345043,  1.15381808, -0.52397911, -0.56984645],
#        [-0.76009617, -0.40460776,  0.96435498, -0.91484332],
#        [-0.67184546, -0.25627484, -0.72474864,  0.94982771]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1195150694983684), 'extend_gap_score': np.float64(-0.09085343366156991)}
# Subgradient norm: 74.15179851673135
# End of iteration 38
#
# Start of iteration 39
# Current alpha: -11.628954382475657
# Current logL: -2943.7554975014027
# Updated alpha: -11.644300108686755
# Updated logL: -2943.639329386275
# New subgradient:
# {'Substitutions': Array([[ 27.09344907, -26.93603002, -14.74334734,  19.33306494],
#        [-12.5301154 ,  22.9775653 ,  21.4376284 ,  18.43025267],
#        [  2.06428092,  14.18232132,  23.34894548, -20.24029929],
#        [  3.99349342,   2.71196197, -15.75595359,  20.54867818]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-12.081797237489647), 'Gap extends': np.float64(15.032336952310535)}
# Stepsize: 5e-05
# Gap open step: -0.0006040898618744824
# Gap extend step: 0.0007516168476155268
# New parameters:
# {'alpha': np.float64(-11.644300108686755), 'substitution_matrix': Array([[ 1.24067286, -0.88605146, -0.79006552, -0.52322487],
#        [-0.78407695,  1.15496695, -0.52290724, -0.56892492],
#        [-0.75999294, -0.40389865,  0.96552241, -0.91585534],
#        [-0.67164579, -0.25613925, -0.72553643,  0.95085514]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1197382175132549), 'extend_gap_score': np.float64(-0.0905013229525897)}
# Subgradient norm: 75.90088113960726
# End of iteration 39
#
# Start of iteration 40
# Current alpha: -11.644300108686755
# ...
# Stepsize: 5e-05
# Gap open step: 0.0015190509100031374
# Gap extend step: 0.011192943992036386
# New parameters:
# {'alpha': np.float64(-12.36264966709321), 'substitution_matrix': Array([[ 1.30925512, -1.0463735 , -0.86585423, -0.47203786],
#        [-0.8924332 ,  1.21502196, -0.41907865, -0.48833843],
#        [-0.75661195, -0.35796431,  1.02518542, -1.03675596],
#        [-0.65660006, -0.22692986, -0.81458585,  1.00816537]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.184138258438723), 'extend_gap_score': np.float64(-0.08858649058585465)}
# Subgradient norm: 229.78453548719452
# End of iteration 186
#
# Start of iteration 187
# Current alpha: -12.36264966709321
# Current logL: -2933.7140581825433
# Updated alpha: -12.476783556117402
# Updated logL: -2927.4829019775034
# New subgradient:
# {'Substitutions': Array([[ -6.34055044, -14.1171849 ,  -6.53752263,   1.57821537],
#        [-11.85592012,   0.39018591,   3.80238047,   6.84519709],
#        [  2.77258236,   2.89473352, -14.41991739, -10.66775486],
#        [  1.57420379,  -0.3029209 ,  -8.63376943,  -3.14174033]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-31.86324993959408), 'Gap extends': np.float64(-238.51035851392476)}
# Stepsize: 5e-05
# Gap open step: -0.001593162496979704
# Gap extend step: -0.011925517925696238
# New parameters:
# {'alpha': np.float64(-12.476783556117402), 'substitution_matrix': Array([[ 1.30893809, -1.04707936, -0.86618111, -0.47195895],
#        [-0.89302599,  1.21504147, -0.41888853, -0.48799617],
#        [-0.75647332, -0.35781957,  1.02446443, -1.03728935],
#        [-0.65652134, -0.22694501, -0.81501753,  1.00800828]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1857879748032327), 'extend_gap_score': np.float64(-0.1005197892303255)}
# Subgradient norm: 242.51597279642374
# End of iteration 187
#
# Start of iteration 188
# Current alpha: -12.476783556117402
# Current logL: -2933.6539990813258
# Updated alpha: -12.361880054188333
# Updated logL: -2927.3916070651976
# New subgradient:
# {'Substitutions': Array([[ 15.02312531, -18.913415  , -12.34040412,  -2.81124277],
#        [-12.25470394,   5.1192905 ,   3.85636795,   6.2246249 ],
#        [ -3.44725293,  -2.95226853,  20.88602903, -10.48477219],
#        [ -0.87619648,  -0.03833281, -10.19166843,  10.09657003]],
#          alphabet='GCTA'), 'Gap opens': np.float64(29.485323769292656), 'Gap extends': np.float64(222.24493178827748)}
# Stepsize: 5e-05
# Gap open step: 0.001474266188464633
# Gap extend step: 0.011112246589413875
# New parameters:
# {'alpha': np.float64(-12.361880054188333), 'substitution_matrix': Array([[ 1.30968925, -1.04802503, -0.86679812, -0.47209951],
#        [-0.89363872,  1.21529744, -0.41869571, -0.48768494],
#        [-0.75664568, -0.35796719,  1.02550873, -1.03781359],
#        [-0.65656515, -0.22694694, -0.81552711,  1.00851312]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.18434290056415), 'extend_gap_score': np.float64(-0.08944014963155197)}
# Subgradient norm: 228.0551040521678
# End of iteration 188
#
# Start of iteration 189
# Current alpha: -12.361880054188333
# Current logL: -2933.2076013611463
# Updated alpha: -12.4737157246943
# Updated logL: -2927.228094166437
# New subgradient:
# {'Substitutions': Array([[ -2.83731904, -13.97658268,  -7.28820234,   1.40937456],
#        [-11.32741022,   1.80713334,   2.47337999,   6.2853672 ],
#        [  3.6808132 ,   2.52752442, -14.61043767, -10.70724261],
#        [  2.30866566,  -0.83236301, -11.22687138,  -3.17573715]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-25.331373539916303), 'Gap extends': np.float64(-217.184620560487)}
# Stepsize: 5e-05
# Gap open step: -0.0012665686769958151
# Gap extend step: -0.01085923102802435
# New parameters:
# {'alpha': np.float64(-12.4737157246943), 'substitution_matrix': Array([[ 1.30954738, -1.04872386, -0.86716253, -0.47202905],
#        [-0.8942051 ,  1.2153878 , -0.41857204, -0.48737066],
#        [-0.75646163, -0.35784081,  1.02477821, -1.03834895],
#        [-0.65644972, -0.22698856, -0.81608846,  1.00835433]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1856780909505331), 'extend_gap_score': np.float64(-0.10031395669141509)}
# Subgradient norm: 220.76399779743085
# End of iteration 189
#
# Start of iteration 190
# Current alpha: -12.4737157246943
# Current logL: -2932.294451693073
# Updated alpha: -12.370485334232077
# Updated logL: -2927.2394368747523
# New subgradient:
# {'Substitutions': Array([[ 11.79681464, -18.50149285, -12.18221758,  -1.16819192],
#        [-11.78903977,   6.64329175,   3.54855465,   6.03655655],
#        [ -5.07763725,  -3.20227398,  22.47767254, -10.63828044],
#        [ -0.7285426 ,   0.06206752,  -9.83601514,  10.19542428]],
#          alphabet='GCTA'), 'Gap opens': np.float64(28.91297110362955), 'Gap extends': np.float64(222.14095847855842)}
# Stepsize: 5e-05
# Gap open step: 0.0014456485551814775
# Gap extend step: 0.011107047923927922
# New parameters:
# {'alpha': np.float64(-12.370485334232077), 'substitution_matrix': Array([[ 1.31013721, -1.04964894, -0.86777164, -0.47208745],
#        [-0.89479455,  1.21571996, -0.41839461, -0.48706883],
#        [-0.75671551, -0.35800092,  1.02590209, -1.03888087],
#        [-0.65648615, -0.22698545, -0.81658025,  1.0088641 ]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1842328724225761), 'extend_gap_score': np.float64(-0.08927826475086731)}
# Subgradient norm: 227.8192903706865
# End of iteration 190
#
# Start of iteration 191
# Current alpha: -12.370485334232077
# Current logL: -2933.1362591579355
# Updated alpha: -12.481884110333935
# Updated logL: -2927.2042188299542
# New subgradient:
# {'Substitutions': Array([[ -1.63784377, -13.16893261,  -7.09868564,   0.87093125],
#        [-11.00051409,   1.43567447,   2.94267842,   6.14479179],
#        [  3.71480841,   3.05081783, -15.32959323,  -9.83852534],
#        [  1.6796104 ,  -0.28181859, -11.09807519,  -2.11225806]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-26.084728877362316), 'Gap extends': np.float64(-210.27468455547398)}
# Stepsize: 5e-05
# Gap open step: -0.001304236443868116
# Gap extend step: -0.0105137342277737
# New parameters:
# {'alpha': np.float64(-12.481884110333935), 'substitution_matrix': Array([[ 1.31005532, -1.05030738, -0.86812658, -0.47204392],
#        [-0.89534458,  1.21579175, -0.41824748, -0.48676159],
#        [-0.75652977, -0.35784838,  1.02513561, -1.03937279],
#        [-0.65640217, -0.22699954, -0.81713516,  1.00875848]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1855036029890778), 'extend_gap_score': np.float64(-0.09975098011139694)}
# Subgradient norm: 213.95800959210356
# End of iteration 191
#
# Start of iteration 192
# Current alpha: -12.481884110333935
# Current logL: -2931.6993172154057
# Updated alpha: -12.382428282131956
# Updated logL: -2927.0069174177074
# New subgradient:
# {'Substitutions': Array([[ 12.27359316, -17.50679027, -11.98144052,   0.12256559],
#        [-11.43050562,   7.38471516,   2.94454525,   6.02306872],
#        [ -4.72324101,  -3.46846645,  22.21118779, -11.21807875],
#        [ -1.58639583,   0.70601439,  -9.3178209 ,  10.65149691]],
#          alphabet='GCTA'), 'Gap opens': np.float64(29.252308164064022), 'Gap extends': np.float64(221.21590035151797)}
# Stepsize: 5e-05
# Gap open step: 0.0014626154082032013
# Gap extend step: 0.011060795017575899
# New parameters:
# {'alpha': np.float64(-12.382428282131956), 'substitution_matrix': Array([[ 1.310669  , -1.05118273, -0.86872565, -0.47203779],
#        [-0.8959161 ,  1.21616098, -0.41810025, -0.48646044],
#        [-0.75676594, -0.3580218 ,  1.02624617, -1.0399337 ],
#        [-0.65648148, -0.22696424, -0.81760105,  1.00929106]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1840449893375171), 'extend_gap_score': np.float64(-0.0886115962736399)}
# Subgradient norm: 226.8916505553883
# End of iteration 192
#
# Start of iteration 193
# Current alpha: -12.382428282131956
# Current logL: -2933.409600299619
# Updated alpha: -12.495487890830809
# Updated logL: -2927.298946579987
# New subgradient:
# {'Substitutions': Array([[ -2.86998888, -12.61944067,  -7.81217908,   1.63952798],
#        [-11.15492681,  -1.39229213,   3.02881347,   7.7408492 ],
#        [  3.2332371 ,   3.7469192 , -13.7685415 ,  -9.63537217],
#        [  2.3380645 ,  -0.88357838, -11.33075763,  -1.58703138]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-28.292107064565467), 'Gap extends': np.float64(-228.1719026570428)}
# Stepsize: 5e-05
# Gap open step: -0.0014146053532282734
# Gap extend step: -0.011408595132852141
# New parameters:
# {'alpha': np.float64(-12.495487890830809), 'substitution_matrix': Array([[ 1.3105255 , -1.0518137 , -0.86911626, -0.47195581],
#        [-0.89647385,  1.21609137, -0.41794881, -0.4860734 ],
#        [-0.75660427, -0.35783445,  1.02555774, -1.04041547],
#        [-0.65636458, -0.22700842, -0.81816759,  1.00921171]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1854431295231544), 'extend_gap_score': np.float64(-0.10004172061950467)}
# Subgradient norm: 231.80506966221142
# End of iteration 193
#
# Start of iteration 194
# Current alpha: -12.495487890830809
# Current logL: -2932.5946498217413
# Updated alpha: -12.38658902747754
# Updated logL: -2926.971411589516
# New subgradient:
# {'Substitutions': Array([[  8.50203959, -17.44305319, -11.90017391,  -0.32851011],
#        [-11.36951297,   8.8564635 ,   1.93786158,   5.58554086],
#        [ -4.76295666,  -3.48584672,  21.38161857, -10.91710217],
#        [ -1.5720492 ,   0.69148493,  -9.79197067,   9.75561562]],
#          alphabet='GCTA'), 'Gap opens': np.float64(26.562965651198418), 'Gap extends': np.float64(218.97286608394523)}
# Stepsize: 5e-05
# Gap open step: 0.001328148282559921
# Gap extend step: 0.010948643304197262
# New parameters:
# {'alpha': np.float64(-12.38658902747754), 'substitution_matrix': Array([[ 1.3109506 , -1.05268585, -0.86971126, -0.47197224],
#        [-0.89704233,  1.21653419, -0.41785191, -0.48579413],
#        [-0.75684243, -0.35800874,  1.02662682, -1.04096132],
#        [-0.65644318, -0.22697385, -0.81865719,  1.00969949]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1840981879802246), 'extend_gap_score': np.float64(-0.08900068411046266)}
# Subgradient norm: 224.10002870060444
# End of iteration 194
#
# Start of iteration 195
# Current alpha: -12.38658902747754
# Current logL: -2932.9957135639484
# Updated alpha: -12.497189379987843
# Updated logL: -2927.1500075687504
# New subgradient:
# {'Substitutions': Array([[ -0.94366056, -12.56963943,  -7.05675905,   1.05240355],
#        [-11.07899732,   0.07651098,   3.21091988,   6.14407954],
#        [  3.07777332,   3.18778217, -14.40566532,  -9.59745913],
#        [  2.39440024,  -0.55586371, -11.67741624,  -0.82033   ]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-24.094595897494084), 'Gap extends': np.float64(-217.51091910641225)}
# Stepsize: 5e-05
# Gap open step: -0.0012047297948747043
# Gap extend step: -0.010875545955320613
# New parameters:
# {'alpha': np.float64(-12.497189379987843), 'substitution_matrix': Array([[ 1.31090342, -1.05331433, -0.8700641 , -0.47191961],
#        [-0.89759628,  1.21653801, -0.41769137, -0.48548692],
#        [-0.75668854, -0.35784936,  1.02590654, -1.04144119],
#        [-0.65632346, -0.22700164, -0.81924106,  1.00965847]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1853335139763788), 'extend_gap_score': np.float64(-0.09989539187379154)}
# Subgradient norm: 220.7589069243293
# End of iteration 195
#
# Start of iteration 196
# Current alpha: -12.497189379987843
# Current logL: -2931.8499670283113
# Updated alpha: -12.394378349255335
# Updated logL: -2926.8379625772964
# New subgradient:
# {'Substitutions': Array([[ 12.73182521, -17.29661254, -12.25136451,  -0.33937707],
#        [-11.69909677,   7.49529516,   2.7311491 ,   5.6331853 ],
#        [ -4.59853051,  -3.33823085,  20.66376687, -10.79390329],
#        [ -1.98355937,   0.7194309 , -10.58259929,  10.38424893]],
#          alphabet='GCTA'), 'Gap opens': np.float64(30.14696265864248), 'Gap extends': np.float64(225.28497177676644)}
# Stepsize: 5e-05
# Gap open step: 0.001507348132932124
# Gap extend step: 0.011264248588838323
# New parameters:
# {'alpha': np.float64(-12.394378349255335), 'substitution_matrix': Array([[ 1.31154001, -1.05417916, -0.87067667, -0.47193658],
#        [-0.89818123,  1.21691278, -0.41755481, -0.48520527],
#        [-0.75691847, -0.35801627,  1.02693973, -1.04198089],
#        [-0.65642264, -0.22696566, -0.81977019,  1.01017768]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1838294109766991), 'extend_gap_score': np.float64(-0.08866144609810711)}
# Subgradient norm: 230.8808136609556
# End of iteration 196
#
# Start of iteration 197
# Current alpha: -12.394378349255335
# Current logL: -2933.3709030976047
# Updated alpha: -12.50823030589642
# Updated logL: -2927.1765512293064
# New subgradient:
# {'Substitutions': Array([[ -3.55462551, -11.8194007 ,  -7.98156782,   1.88280832],
#        [-10.96165958,  -1.8756138 ,   3.3172776 ,   7.91497926],
#        [  3.46164649,   3.7774355 , -14.00097543,  -9.66868526],
#        [  3.25402136,  -0.92416685, -11.50126355,  -2.11086125]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-30.30615809941544), 'Gap extends': np.float64(-235.0262226254657)}
# Stepsize: 5e-05
# Gap open step: -0.0015153079049707722
# Gap extend step: -0.011751311131273286
# New parameters:
# {'alpha': np.float64(-12.50823030589642), 'substitution_matrix': Array([[ 1.31136228, -1.05477012, -0.87107575, -0.47184243],
#        [-0.89872931,  1.216819  , -0.41738894, -0.48480952],
#        [-0.75674538, -0.3578274 ,  1.02623968, -1.04246432],
#        [-0.65625994, -0.22701187, -0.82034525,  1.01007214]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1854138325404127), 'extend_gap_score': np.float64(-0.10041396824775602)}
# Subgradient norm: 238.82344632681588
# End of iteration 197
#
# Start of iteration 198
# Current alpha: -12.50823030589642
# Current logL: -2932.884604979968
# Updated alpha: -12.395494082826078
# Updated logL: -2926.861474550045
# New subgradient:
# {'Substitutions': Array([[  9.09733559, -17.11191679, -11.69195629,  -0.5547686 ],
#        [-11.22978432,   8.72770731,   1.36171454,   4.8288816 ],
#        [ -3.98011685,  -3.54105973,  21.40189228, -10.38057747],
#        [ -1.42761785,   1.52467408, -11.37725529,  10.15581446]],
#          alphabet='GCTA'), 'Gap opens': np.float64(27.96597744613913), 'Gap extends': np.float64(225.6914142226177)}
# Stepsize: 5e-05
# Gap open step: 0.0013982988723069566
# Gap extend step: 0.011284570711130886
# New parameters:
# {'alpha': np.float64(-12.395494082826078), 'substitution_matrix': Array([[ 1.31181714, -1.05562572, -0.87166035, -0.47187017],
#        [-0.8992908 ,  1.21725539, -0.41732086, -0.48456808],
#        [-0.75694439, -0.35800445,  1.02730977, -1.04298334],
#        [-0.65633132, -0.22693564, -0.82091411,  1.01057993]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1840245649060128), 'extend_gap_score': np.float64(-0.08912009924946263)}
# Subgradient norm: 230.84599645012457
# End of iteration 198
#
# Start of iteration 199
# Current alpha: -12.395494082826078
# Current logL: -2933.116522340573
# Updated alpha: -12.508575909332592
# Updated logL: -2927.007802275926
# New subgradient:
# {'Substitutions': Array([[ -1.72410813, -11.95618735,  -7.38194227,   0.95380563],
#        [-10.89719293,   0.45078533,   3.0114477 ,   6.03641988],
#        [  3.27883968,   3.12623394, -14.19639756,  -9.45149357],
#        [  2.94643451,  -0.96907394, -11.33284687,  -1.97736635]],
#          alphabet='GCTA'), 'Gap opens': np.float64(-25.43369418511558), 'Gap extends': np.float64(-217.31884213456755)}
# Stepsize: 5e-05
# Gap open step: -0.001271684709255779
# Gap extend step: -0.010865942106728378
# New parameters:
# {'alpha': np.float64(-12.508575909332592), 'substitution_matrix': Array([[ 1.31173094, -1.05622353, -0.87202945, -0.47182248],
#        [-0.89983566,  1.21727793, -0.41717028, -0.48426626],
#        [-0.75678045, -0.35784814,  1.02659995, -1.04345592],
#        [-0.65618399, -0.2269841 , -0.82148076,  1.01048106]],
#          alphabet='GCTA'), 'open_gap_score': np.float64(-1.1851905329697283), 'extend_gap_score': np.float64(-0.10008519066004118)}
# Subgradient norm: 220.66602159418775
# End of iteration 199

# %%
print(params['final_loglik'])
# Out:
# -2931.755443027663

# %%
plt.figure()
plt.subplot(221)
plt.plot(np.arange(NITER), params['subgradient_l2_trajectory'])
plt.plot([0, NITER], [0, 0], 'k--')
plt.title('Subgradient L2 norm trajectory')


plt.subplot(222)
plt.plot(np.arange(NITER+1), params['loglik_trajectory'])
plt.plot([0, NITER+1], [true_logL, true_logL], 'k--')
plt.title('LogLikelihood trajectory')


plt.subplot(223)
plt.plot(np.arange(NITER//2, NITER), params['subgradient_l2_trajectory'][NITER//2:])
plt.plot([NITER//2, NITER], [0, 0], 'k--')
plt.title('Subgradient L2 norm trajectory')

plt.subplot(224)
plt.plot(np.arange(NITER//2, NITER+1), params['loglik_trajectory'][NITER//2:])
plt.plot([NITER//2, NITER+1], [true_logL, true_logL], 'k--')
plt.title('LogLikelihood trajectory')

plt.tight_layout()

# %%
print(true_gapopen, params['open_gap_score'])
print(true_gapext, params['extend_gap_score'])
print(true_alpha, params['alpha'])
true_subs_vector = []
param_subs_vector = []
for char1 in true_substitution.alphabet:
    for char2 in true_substitution.alphabet:
        true_v = true_substitution[char1, char2]
        true_subs_vector.append(true_v)
        estim_v = params['substitution_matrix'][char1, char2]
        param_subs_vector.append(estim_v)
        print(char1, char2, true_v, estim_v)
        
print(np.corrcoef(true_subs_vector, param_subs_vector))
print(np.mean(np.abs(np.array(true_subs_vector)- np.array(param_subs_vector)))) # mean asolute error calculation vs correlation boxplot for 20 replicates (data already present)
# Out:
# -1.2 -1.1851905329697283
# -0.1 -0.10008519066004118
# -12 -12.508575909332592
# A A 1.0 1.0104810615788193
# A C -0.3 -0.22698409597437372
# A T -1.0 -0.8214807581847762
# A G -0.8 -0.6561839939193942
# C A -0.6 -0.48426625859883055
# C C 1.2 1.2172779269001817
# C T -0.3 -0.41717028239192755
# C G -1.0 -0.8998356615237482
# T A -1.2 -1.0434559189566939
# T C -0.4 -0.3578481356855115
# T T 1.0 1.026599951981614
# T G -0.8 -0.7567804457349925
# G A -0.4 -0.4718224804451187
# G C -1.4 -1.056223528410227
# G T -0.9 -0.8720294472245051
# G G 1.3 1.311730936456145
# [[1.         0.99427657]
#  [0.99427657 1.        ]]
# 0.09249964972129707

# %%
plt.figure(figsize=FIGSIZE)

plt.plot(true_subs_vector, param_subs_vector, 'r.')

plt.xlabel("True substitution weight")
plt.ylabel("DiscrimAlign estimated weight")

plt.tight_layout()
ax = plt.gca()
xmin, xmax = ax.get_xlim()
ax.set_xticks(np.linspace(-2, 1, 4))
ax.set_xlim(xmin, xmax)

ax.set_yticks(np.linspace(*ax.get_ylim(), 4, dtype=int))
plt.savefig("results/general/true_vs_estimated_submatrix.png", dpi=DPI)

# %%
from src.optimization import get_initial_estimate

# %%
get_initial_estimate(params['alignments'], labels, substitution_mode='general', gap_mode='affine',
                     alphabet=true_substitution.alphabet)
# Out:
# {'alpha': np.float64(-12.682524776500578),
#  'substitution_matrix': Array([[ 1.03658738, -0.21717569, -0.92129275, -0.68208361],
#         [-0.4713911 ,  1.24322242, -0.42008332, -1.03595458],
#         [-1.1596995 , -0.37145556,  1.05582003, -0.79676399],
#         [-0.48423113, -1.35230841, -0.97960697,  1.34063997]],
#           alphabet='ACTG'),
#  'open_gap_score': np.float64(-1.2177512774567372),
#  'extend_gap_score': np.float64(-0.09605980120352103)}

# %%
true_substitution
# Out:
# Array([[ 1. , -0.3, -1. , -0.8],
#        [-0.6,  1.2, -0.3, -1. ],
#        [-1.2, -0.4,  1. , -0.8],
#        [-0.4, -1.4, -0.9,  1.3]],
#          alphabet='ACTG')

# %%
estim_substitution = true_substitution.copy()
for char1 in true_substitution.alphabet:
    for char2 in true_substitution.alphabet:
        estim_substitution[char1, char2] = params['substitution_matrix'][char1, char2]

# %%
estim_substitution
# Out:
# Array([[ 1.01048106, -0.2269841 , -0.82148076, -0.65618399],
#        [-0.48426626,  1.21727793, -0.41717028, -0.89983566],
#        [-1.04345592, -0.35784814,  1.02659995, -0.75678045],
#        [-0.47182248, -1.05622353, -0.87202945,  1.31173094]],
#          alphabet='ACTG')

# %% [markdown]
# ### Step function parameters experiment

# %%
labels = rd.rand(len(mirlist)) <= logit_scores

# %%
true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))

# %%
steplengths = np.linspace(0.000005, 0.00005, num=10)
steplengths
# Out:
# array([5.0e-06, 1.0e-05, 1.5e-05, 2.0e-05, 2.5e-05, 3.0e-05, 3.5e-05,
#        4.0e-05, 4.5e-05, 5.0e-05])

# %%
NITER = 200

# %%
# Get the iteration at which logL is hit (speed)
def get_logL__reached_iter(params, true_logL):
    for i, logL in enumerate(params['loglik_trajectory']):
        if logL >= true_logL:
            return i
    return None

# %%
# Get the value at the last iteration of the simulation
def get_final_val_avg(params):
    return np.mean(params['loglik_trajectory'][-20:])

# %%
pickle_path = "results/general/step_experiment_general.pkl"

if os.path.exists(pickle_path):
    with open(pickle_path, "rb") as f:
        saved = pickle.load(f)

    labels = saved["labels"]
    true_logL = saved["true_logL"]
    estimalign_results_step = saved["estimalign_results_step"]
    logL_reached_iters = saved["logL_reached_iters"]
    final_vals = saved["final_vals"]

else:
    
    labels = rd.rand(len(mirlist)) <= logit_scores
    true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))
    
    estimalign_results_step = []

    logL_reached_iters = []
    final_vals = []

    for stepl in steplengths:
        const_step = create_constant_step(stepl)
        
        params = estimalign(mirlist, genelist, labels, 
                        stepfunction=const_step,
                        aligner_mode='local',
                        substitution_mode='general', ## changed 
                        gap_mode = 'affine',
                        verbose=False, max_iter=NITER,
                        stochastic_factor=0.001,
                        num_threads = 16)
        estimalign_results_step.append(params)

        logL_reached_iter = get_logL__reached_iter(params, true_logL)
        logL_reached_iters.append(logL_reached_iter if logL_reached_iter is not None else np.inf) # infinity so that they dont show on the scatter plot 

        final_val = get_final_val_avg(params)
        final_vals.append(final_val)

        if logL_reached_iter is not None:
            print(f"step {stepl:.2e}, surpassed logL at iteration {logL_reached_iter} and reached a maximum value of {final_val}")
        else:
            print(f"step {stepl:.2e} did NOT hit logL")
    
    with open(pickle_path, "wb") as f:
        pickle.dump(
            {
                "labels": labels,
                "true_logL": true_logL,
                "estimalign_results_step": estimalign_results_step,
                "logL_reached_iters": logL_reached_iters,
                "final_vals": final_vals,
                "steplengths": steplengths,
                "NITER": NITER,
            },
            f
        )

# %%
step_colors = plt.cm.tab10(np.linspace(0, 1, len(steplengths)))

plt.figure(figsize=FIGSIZE)
for params,color in zip(estimalign_results_step, step_colors):
    plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)
plt.plot([0, NITER], [true_logL, true_logL], 'k--')

plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")
ax = plt.gca()
ax.set_xticks(np.linspace(0, 200, 5, dtype=int))
ax.set_yticks(np.linspace(*ax.get_ylim(), 4))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

plt.tight_layout()
plt.savefig("results/general/step_experiment_full_trajectories_general.png", dpi=DPI)

# %%
# zoom on start
plt.figure(figsize=FIGSIZE)
for params,color in zip(estimalign_results_step, step_colors):
    plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)
plt.plot([0, NITER], [true_logL, true_logL], 'k--')

plt.xlim(0, 15)
plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")
ax = plt.gca()
ax.set_xticks(np.linspace(0, 15, 5, dtype=int))
ax.set_yticks(np.linspace(*ax.get_ylim(), 4))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

plt.tight_layout()
plt.savefig("results/general/step_experiment_zoom_start_general.png", dpi=DPI)

# %%
# # zoom where most trajectories hit logL
# plt.figure(figsize=FIGSIZE)
# for params,color in zip(estimalign_results_step, step_colors):
#     plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)
# plt.plot([0, NITER], [true_logL, true_logL], 'k--')

# plt.xlim(25, NITER) 
# all_vals = np.concatenate([
#     np.array(p['loglik_trajectory'])[25:]
#     for p in estimalign_results_step
# ])

# ymin, ymax = all_vals.min(), all_vals.max()
# plt.ylim(ymin, 0.9999 * ymax)
# plt.xlabel("Iteration")
# plt.ylabel("Log-likelihood")

# ax = plt.gca()
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# plt.tight_layout()
# plt.savefig("results/general/step_experiment_zoom_mid_general.png", dpi=DPI)

# %%
# zoom on the end of the iterations
plt.figure(figsize=FIGSIZE)

for params,color in zip(estimalign_results_step, step_colors):
    plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)
    
plt.plot([0, NITER], [true_logL, true_logL], 'k--')


plt.xlim(NITER-20, NITER)

# collect only last 20 iterations
all_vals = np.concatenate([
    np.array(p['loglik_trajectory'])[NITER-20:]
    for p in estimalign_results_step
])

#sort and drop lowest x % 
sorted_vals = np.sort(all_vals)
cutoff = int(0.2 * len(sorted_vals))  # remove lowest x%
trimmed_vals = sorted_vals[cutoff:]

ymin = trimmed_vals.min()
ymax = trimmed_vals.max()

pad = 0.05 * (ymax - ymin)

plt.ylim(ymin, ymax + pad)

ax = plt.gca()
ax.set_xticks(np.linspace(180, 200, 5, dtype=int))
ax.set_yticks(np.linspace(*ax.get_ylim(), 4))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")

plt.tight_layout()
plt.savefig("results/general/step_experiment_zoom_end_general.png", dpi=DPI)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter


plt.figure(figsize=FIGSIZE)

logL_reached_iters_arr = np.array(logL_reached_iters)
final_vals_arr = np.array(final_vals)
steplengths_arr = np.array(steplengths)

mask = np.isfinite(logL_reached_iters_arr)

# Get unique step sizes
unique_steps = np.sort(np.unique(steplengths_arr[mask]))

# Use a discrete colormap
cmap = plt.cm.get_cmap("tab10", len(unique_steps))

for i, s in enumerate(unique_steps):
    idx = (steplengths_arr == s) & mask

    plt.scatter(
        final_vals_arr[idx],
        logL_reached_iters_arr[idx],
        color=cmap(i),
        s=60,
        label=f"{s:.2e}",
        alpha=0.85
    )

plt.ylabel("First iteration which hits true logL")
plt.xlabel("Average log-likelihood at last 20 iterations")


ax = plt.gca()
xmin, xmax = ax.get_xlim()
ax.set_xticks(np.linspace(xmin, xmax, 5))
ax.set_xlim(xmin, xmax)

ax.set_yticks(np.linspace(*ax.get_ylim(), 4, dtype=int))

plt.tight_layout()
plt.savefig("results/general/step_experiment_scatter_hit_vs_final_general.png", dpi=DPI)
# Out:
# /tmp/ipykernel_50373/1231280037.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(unique_steps))

# %% [markdown]
# ### Replicates

# %%
REPS = 20 #20
NITER = 200

# %%
const_step = create_constant_step(4.0e-05) # choose best step from prev exp 
# const_step = create_constant_step(0.00001)
# powerstep = create_powerstep(0.00001, power=0.5, burnin=0)
# powerstep = create_powerstep(0.00001, power=-0.5, burnin=0)

# %%
# Checks if the chosen step size is stable in convergence across different datasets
pickle_path = "results/general/replicates_general.pkl"

if os.path.exists(pickle_path):
    with open(pickle_path, "rb") as f:
        saved = pickle.load(f)

    estimalign_results_rep = saved["estimalign_results_rep"]
    true_logLs = saved["true_logLs"]
    logL_reached_iters_rep = saved["logL_reached_iters_rep"]
    final_vals_rep = saved["final_vals_rep"]

else:

    estimalign_results_rep = []
    true_logLs = []

    logL_reached_iters_rep = []
    final_vals_rep = []

    for _ in range(REPS):
        labels = rd.rand(len(mirlist)) <= logit_scores
        true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))
        true_logLs.append(true_logL)
        params = estimalign(mirlist, genelist, labels, 
                        stepfunction=const_step,
                        aligner_mode='local',
                        substitution_mode='general', ## changed
                        gap_mode = 'affine',
                        verbose=False, max_iter=NITER,
                        stochastic_factor=0.001,
                        num_threads = 16)
        estimalign_results_rep.append(params)

        logL_reached_iter = get_logL__reached_iter(params, true_logL)
        
        logL_reached_iters_rep.append(
            logL_reached_iter if logL_reached_iter is not None else np.inf
        )

        final_vals_rep.append(get_final_val_avg(params))

    for i, it in enumerate(logL_reached_iters_rep):
        if np.isfinite(it):
            print(f"rep {i} hit logL at iteration {it}, final={final_vals_rep[i]:.2f}")
        else:
            print(f"rep {i} did NOT hit logL, final={final_vals_rep[i]:.2f}")

    with open(pickle_path, "wb") as f:
        pickle.dump(
            {
                "estimalign_results_rep": estimalign_results_rep,
                "true_logLs": true_logLs,
                "logL_reached_iters_rep": logL_reached_iters_rep,
                "final_vals_rep": final_vals_rep,
                "REPS": REPS,
                "NITER": NITER,
            },
            f
        )

# %%
plt.figure(figsize=FIGSIZE)

for params in estimalign_results_rep:
    plt.plot(
        np.arange(NITER + 1),
        params['loglik_trajectory'],
        alpha=0.2,
        color='b'
    )

plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")

ax = plt.gca()

xmin, xmax = ax.get_xlim()
ax.set_xticks(np.linspace(0, 200, 5, dtype=int))
ax.set_xlim(xmin, xmax)

ax.set_yticks(np.linspace(*ax.get_ylim(), 4, dtype=int))

plt.tight_layout()
plt.savefig("results/general/replicates_loglik_trajectories_general.png", dpi=DPI)

# %%
plt.figure(figsize=FIGSIZE)

plt.plot([0, NITER], [0, 0], 'k--')

for params, tlL in zip(estimalign_results_rep, true_logLs):
    plt.plot(
        np.arange(NITER + 1),
        tlL - np.array(params['loglik_trajectory']),
        alpha=0.2,
        color='b'
    )

plt.xlabel("Iteration")
plt.ylabel("True logL minus estimated logL")

ax = plt.gca()

xmin, xmax = ax.get_xlim()
ax.set_xticks(np.linspace(0, 200, 5, dtype=int))
ax.set_xlim(xmin, xmax)


ymin, ymax = ax.get_ylim()
ax.set_yticks(np.linspace(0, ymax+1, 4, dtype=int))
plt.tight_layout()
plt.savefig("results/general/replicates_loglik_gap_general.png", dpi=DPI)

# %%
rep_corrs = []
rep_maes = []

for params in estimalign_results_rep:
    print(true_gapopen, params['open_gap_score'])
    print(true_gapext, params['extend_gap_score'])
    print(true_alpha, params['alpha'])

    true_subs_vector = []
    param_subs_vector = []

    for char1 in true_substitution.alphabet:
        for char2 in true_substitution.alphabet:
            true_v = true_substitution[char1, char2]
            estim_v = params['substitution_matrix'][char1, char2]

            true_subs_vector.append(true_v)
            param_subs_vector.append(estim_v)

            print(char1, char2, true_v, estim_v)

    true_subs_vector = np.array(true_subs_vector)
    param_subs_vector = np.array(param_subs_vector)

    corr = np.corrcoef(true_subs_vector, param_subs_vector)[0, 1]
    mae = np.mean(np.abs(true_subs_vector - param_subs_vector))

    print(np.corrcoef(true_subs_vector, param_subs_vector))
    print(mae)

    rep_corrs.append(corr)
    rep_maes.append(mae)

rep_corrs = np.array(rep_corrs)
rep_maes = np.array(rep_maes)
# Out:
# -1.2 -1.2372038118661783
# -0.1 -0.0971217122795078
# -12 -11.758288826696905
# A A 1.0 0.9679770142015088
# A C -0.3 -0.32798554508769556
# A T -1.0 -1.0182532371313586
# A G -0.8 -0.7553692578353035
# C A -0.6 -0.6637291240323178
# C C 1.2 1.187560283884012
# C T -0.3 -0.2646349966121609
# C G -1.0 -0.861989416966994
# T A -1.2 -1.1255919811546542
# T C -0.4 -0.42192992664949597
# T T 1.0 1.0124477802684704
# T G -0.8 -0.7756496887494916
# G A -0.4 -0.47153171016868584
# G C -1.4 -0.9806976700856151
# G T -0.9 -0.8537582120852466
# G G 1.3 1.2857596761865757
# [[1.       0.992721]
#  [0.992721 1.      ]]
# 0.06605557034852884
# -1.2 -1.143513633916548
# -0.1 -0.09485173239945481
# -12 -11.739980947764192
# A A 1.0 0.9899975623932752
# A C -0.3 -0.24946845173817805
# A T -1.0 -0.7989695733286434
# A G -0.8 -0.6714257006473819
# C A -0.6 -0.594469322229207
# C C 1.2 1.1619412323296165
# C T -0.3 -0.27552181636995154
# C G -1.0 -0.9371000422467883
# T A -1.2 -1.0001836847502663
# T C -0.4 -0.42804590547072735
# T T 1.0 0.958672037794885
# T G -0.8 -0.743449158382732
# G A -0.4 -0.4503386548555032
# G C -1.4 -0.9569785206490313
# G T -0.9 -0.7990077398290063
# G G 1.3 1.259724882679967
# [[1.         0.99336298]
#  [0.99336298 1.        ]]
# 0.09259217718483129
# -1.2 -1.1303065968186852
# -0.1 -0.0939495790998753
# -12 -11.15524787951975
# A A 1.0 0.897406005063174
# A C -0.3 -0.4035231312975918
# A T -1.0 -0.8947610988989465
# A G -0.8 -0.7541000368498303
# C A -0.6 -0.6819616599156682
# C C 1.2 1.1364841634455851
# C T -0.3 -0.273024423548147
# C G -1.0 -0.8406589843986995
# T A -1.2 -1.129013800309832
# T C -0.4 -0.42769829600672377
# T T 1.0 0.9363768753000524
# T G -0.8 -0.829559392851032
# G A -0.4 -0.43681678730854656
# G C -1.4 -1.014730929147751
# G T -0.9 -0.6812369551064975
# G G 1.3 1.2362072379278906
# [[1.         0.99233329]
#  [0.99233329 1.        ]]
# 0.09909742233644726
# -1.2 -1.1609612917402605
# -0.1 -0.10357863790688969
# -12 -11.881347875261381
# A A 1.0 0.9892879134918007
# A C -0.3 -0.301426444074631
# A T -1.0 -0.8392962863522552
# A G -0.8 -0.7433677037659094
# C A -0.6 -0.5202858242476275
# C C 1.2 1.1884009486721736
# C T -0.3 -0.33340098575682375
# C G -1.0 -0.9712146292529611
# T A -1.2 -1.1347092745485536
# T C -0.4 -0.4147879623277015
# T T 1.0 0.9691466876623327
# T G -0.8 -0.6947029300742324
# G A -0.4 -0.4234537898239197
# G C -1.4 -0.9118132439232902
# G T -0.9 -0.6691771360538199
# G G 1.3 1.2774919735190837
# [[1.         0.99127642]
#  [0.99127642 1.        ]]
# 0.08526091440118974
# -1.2 -1.1634186240024018
# -0.1 -0.09075312472639678
# -12 -11.960640041573264
# A A 1.0 0.9765852954582713
# A C -0.3 -0.3504883165888216
# A T -1.0 -0.9106328288425934
# A G -0.8 -0.8762729369992988
# C A -0.6 -0.5289789860490576
# C C 1.2 1.1759428816012458
# C T -0.3 -0.2412124905557616
# C G -1.0 -0.8791634159745063
# T A -1.2 -1.0496727826376278
# T C -0.4 -0.31775354065308814
# T T 1.0 0.9639558636846249
# T G -0.8 -0.7139692785654496
# G A -0.4 -0.4625804522326382
# G C -1.4 -1.0517603063764316
# G T -0.9 -0.7014478078036964
# G G 1.3 1.2930015466671707
# [[1.         0.99444857]
#  [0.99444857 1.        ]]
# 0.09282904255945208
# -1.2 -1.1995697223268607
# -0.1 -0.09381045094972713
# -12 -11.709909803882292
# A A 1.0 0.9810821269209087
# A C -0.3 -0.3592586573058706
# A T -1.0 -0.8008191359432982
# A G -0.8 -0.6884406939004778
# C A -0.6 -0.6469704920115611
# C C 1.2 1.1945764583368992
# C T -0.3 -0.32363924633811975
# C G -1.0 -0.9137851203083103
# T A -1.2 -1.1142918315041477
# T C -0.4 -0.524248764063823
# T T 1.0 0.9593298904246991
# T G -0.8 -0.7249057923252662
# G A -0.4 -0.4435339877888593
# G C -1.4 -0.9787192253362395
# G T -0.9 -0.7801498407358692
# G G 1.3 1.2747300183936998
# [[1.         0.99153732]
#  [0.99153732 1.        ]]
# 0.09292631333615112
# -1.2 -1.1166995942226698
# -0.1 -0.09311666426650808
# -12 -11.281904898374373
# A A 1.0 0.9158748310086577
# A C -0.3 -0.18953007877765454
# A T -1.0 -0.8773506956022243
# A G -0.8 -0.7226622267030639
# C A -0.6 -0.5051775585128309
# C C 1.2 1.107513190903733
# C T -0.3 -0.22090443236183194
# C G -1.0 -0.5626354335932071
# T A -1.2 -1.0384478097198055
# T C -0.4 -0.38953414615226123
# T T 1.0 0.9344544396223022
# T G -0.8 -0.8046230960830971
# G A -0.4 -0.4207868958579752
# G C -1.4 -0.9033249436311213
# G T -0.9 -0.8524057887066633
# G G 1.3 1.2199022223415001
# [[1.         0.98848199]
#  [0.98848199 1.        ]]
# 0.12410576214401345
# -1.2 -1.1505156814423438
# -0.1 -0.10205700912316025
# -12 -12.23257029283438
# A A 1.0 0.9772959992338444
# A C -0.3 -0.3249145683376967
# A T -1.0 -0.7200347873865494
# A G -0.8 -0.7043438347288751
# C A -0.6 -0.550271859243753
# C C 1.2 1.2092661959767763
# C T -0.3 -0.27633760007953856
# C G -1.0 -0.8897450029697024
# T A -1.2 -1.1242848851137146
# T C -0.4 -0.402381014668337
# T T 1.0 0.9790225137168053
# T G -0.8 -0.9032346115431841
# G A -0.4 -0.3531057463832275
# G C -1.4 -0.8598674353227442
# G T -0.9 -0.7385019426636976
# G G 1.3 1.3211453832646445
# [[1.        0.9878294]
#  [0.9878294 1.       ]]
# 0.09925813543426167
# -1.2 -1.1972932532222544
# -0.1 -0.09161809246356174
# -12 -11.772673738900133
# A A 1.0 0.9660310526646623
# A C -0.3 -0.2825901218197755
# A T -1.0 -0.9965064761118317
# A G -0.8 -0.7098034471939828
# C A -0.6 -0.5446267446972496
# C C 1.2 1.185673732144801
# C T -0.3 -0.22636888357836432
# C G -1.0 -0.9245323560025807
# T A -1.2 -0.9912027300169466
# T C -0.4 -0.3378034369948654
# T T 1.0 0.9485333239074482
# T G -0.8 -0.6854238149019103
# G A -0.4 -0.39569238979230975
# G C -1.4 -0.8884407275995887
# G T -0.9 -0.8189986452676177
# G G 1.3 1.2810913351355657
# [[1.         0.99212142]
#  [0.99212142 1.        ]]
# 0.08854254888565624
# -1.2 -1.1371144505914013
# -0.1 -0.09480951967644632
# -12 -11.558701113542662
# A A 1.0 0.954585835271606
# A C -0.3 -0.37181890519817307
# A T -1.0 -0.8870103209218626
# A G -0.8 -0.7423229536677621
# C A -0.6 -0.6513484753031911
# C C 1.2 1.1508940368514584
# C T -0.3 -0.2540865513390134
# C G -1.0 -0.9860475996554344
# T A -1.2 -1.0017767781060998
# T C -0.4 -0.43208394549490525
# T T 1.0 0.9729653757030408
# T G -0.8 -0.7424573371590387
# G A -0.4 -0.5004872076040888
# G C -1.4 -0.8925590850958551
# G T -0.9 -0.740059532741682
# G G 1.3 1.2350165695816735
# [[1.         0.98917345]
#  [0.98917345 1.        ]]
# 0.09974728484411446
# -1.2 -1.1678123260588091
# -0.1 -0.09776916677554662
# -12 -11.935832051550838
# A A 1.0 0.9700808278169348
# A C -0.3 -0.3093195514108529
# A T -1.0 -0.9267378098223497
# A G -0.8 -0.6852037738569812
# C A -0.6 -0.5269043860491703
# C C 1.2 1.1776017654658908
# C T -0.3 -0.2912087774306213
# C G -1.0 -0.8460557993488846
# T A -1.2 -1.041670392800386
# T C -0.4 -0.4166659422971852
# T T 1.0 0.9949234813805223
# T G -0.8 -0.7892792951535368
# G A -0.4 -0.39105842563653487
# G C -1.4 -1.0230407406908335
# G T -0.9 -0.7622923417958559
# G G 1.3 1.287952885299672
# [[1.         0.99566268]
#  [0.99566268 1.        ]]
# 0.07574842444749148
# -1.2 -1.1694529567724659
# -0.1 -0.10642860766446229
# -12 -11.984569920058211
# A A 1.0 1.007066323437037
# A C -0.3 -0.30407565153591
# A T -1.0 -0.9436906922456162
# A G -0.8 -0.8021767555838011
# C A -0.6 -0.5512248848400855
# C C 1.2 1.1963568977020278
# C T -0.3 -0.4107399376648695
# C G -1.0 -0.8205548885019086
# T A -1.2 -1.0263843900430052
# T C -0.4 -0.43242869323647215
# T T 1.0 1.002812916173012
# T G -0.8 -0.5672878641118314
# G A -0.4 -0.3737096923376175
# G C -1.4 -0.9845881598125468
# G T -0.9 -0.780147052609426
# G G 1.3 1.2595964262960677
# [[1.         0.99208286]
#  [0.99208286 1.        ]]
# 0.09098495807068555
# -1.2 -1.1380044531988578
# -0.1 -0.0951696670302184
# -12 -11.72061998948893
# A A 1.0 0.9979218775858698
# A C -0.3 -0.3760731327729378
# A T -1.0 -0.836265393897997
# A G -0.8 -0.6971763527130824
# C A -0.6 -0.5323135576504191
# C C 1.2 1.1502947217290158
# C T -0.3 -0.23168148723809562
# C G -1.0 -0.8220939752928079
# T A -1.2 -1.038705095283725
# T C -0.4 -0.46321363606535393
# T T 1.0 0.9429038927756201
# T G -0.8 -0.8532755809337385
# G A -0.4 -0.3841268043667509
# G C -1.4 -0.9596947292105575
# G T -0.9 -0.8072563939165395
# G G 1.3 1.2511247175474807
# [[1.         0.99234193]
#  [0.99234193 1.        ]]
# 0.1025627094102543
# -1.2 -1.2200137343136384
# -0.1 -0.09189228171816581
# -12 -11.807342375404765
# A A 1.0 0.9786236708482839
# A C -0.3 -0.29855788749263956
# A T -1.0 -0.9326854353351439
# A G -0.8 -0.6588745221737529
# C A -0.6 -0.5946304739580494
# C C 1.2 1.1979932323694387
# C T -0.3 -0.28365466345648305
# C G -1.0 -0.8212327101517105
# T A -1.2 -1.1344880969175324
# T C -0.4 -0.43850240326456114
# T T 1.0 0.9851732977396827
# T G -0.8 -0.8119365956529213
# G A -0.4 -0.46007982451810914
# G C -1.4 -1.0904453411955466
# G T -0.9 -0.8726274997456831
# G G 1.3 1.2778103224204902
# [[1.         0.99567372]
#  [0.99567372 1.        ]]
# 0.06148260435194716
# -1.2 -1.1263852607939289
# -0.1 -0.10126820961049546
# -12 -11.525971016472024
# A A 1.0 0.9761671463112885
# A C -0.3 -0.3913460783272155
# A T -1.0 -0.890147719405994
# A G -0.8 -0.7695998631758617
# C A -0.6 -0.560684767539085
# C C 1.2 1.1537331116177625
# C T -0.3 -0.30108739830827097
# C G -1.0 -0.7855168934069653
# T A -1.2 -1.0629913385934784
# T C -0.4 -0.3525593356404602
# T T 1.0 0.949839117030427
# T G -0.8 -0.6474687162027221
# G A -0.4 -0.38807886220042187
# G C -1.4 -0.9456988160576237
# G T -0.9 -0.7116567784841045
# G G 1.3 1.2281978674791096
# [[1.         0.99296574]
#  [0.99296574 1.        ]]
# 0.10438082146813638
# -1.2 -1.2187913560547603
# -0.1 -0.09375919103931324
# -12 -12.10712823442471
# A A 1.0 1.0113397612467883
# A C -0.3 -0.36308418126280606
# A T -1.0 -0.8190849019678431
# A G -0.8 -0.8028012694100174
# C A -0.6 -0.6337492767435388
# C C 1.2 1.2054034760288077
# C T -0.3 -0.38187544815073227
# C G -1.0 -1.0244094005420519
# T A -1.2 -0.9672186040764953
# T C -0.4 -0.4323911025875288
# T T 1.0 0.9814478913373644
# T G -0.8 -0.6694947358981403
# G A -0.4 -0.42324517544506
# G C -1.4 -1.0220910098598008
# G T -0.9 -0.7040303627024302
# G G 1.3 1.3080676016974941
# [[1.        0.9911661]
#  [0.9911661 1.       ]]
# 0.08893744920454694
# -1.2 -1.1710899158327583
# -0.1 -0.1020664976561845
# -12 -12.140452452466134
# A A 1.0 0.9737250733341812
# A C -0.3 -0.17900838993803508
# A T -1.0 -0.8484763744019986
# A G -0.8 -0.6469475933464388
# C A -0.6 -0.4796773528492117
# C C 1.2 1.196901405311879
# C T -0.3 -0.2620248896832511
# C G -1.0 -0.7153346317229377
# T A -1.2 -1.171872319805573
# T C -0.4 -0.297685149007567
# T T 1.0 0.9874039984480077
# T G -0.8 -0.8135196117976711
# G A -0.4 -0.4738815785806716
# G C -1.4 -0.9745266447890338
# G T -0.9 -0.7964284155782013
# G G 1.3 1.3036503019211827
# [[1.         0.99240757]
#  [0.99240757 1.        ]]
# 0.10381495338020057
# -1.2 -1.2243222914885523
# -0.1 -0.0927723767644443
# -12 -11.999093319203503
# A A 1.0 0.9827879637442941
# A C -0.3 -0.3906177796246212
# A T -1.0 -0.8485755650953466
# A G -0.8 -0.7544827706226853
# C A -0.6 -0.5890657189860612
# C C 1.2 1.1970404389450882
# C T -0.3 -0.2314581762486498
# C G -1.0 -0.9613064412229659
# T A -1.2 -1.0459506727491104
# T C -0.4 -0.43359410221394457
# T T 1.0 0.9813104144059625
# T G -0.8 -0.7083168019574444
# G A -0.4 -0.5012353363374181
# G C -1.4 -1.0175544086239494
# G T -0.9 -0.8157572431361174
# G G 1.3 1.3159260471257113
# [[1.         0.99334223]
#  [0.99334223 1.        ]]
# 0.08173541559775124
# -1.2 -1.1551864832321346
# -0.1 -0.08566717604799191
# -12 -11.684686544795774
# A A 1.0 0.918164604732474
# A C -0.3 -0.16667644391209638
# A T -1.0 -0.9947612472943306
# A G -0.8 -0.7779089198107375
# C A -0.6 -0.5912295637198338
# C C 1.2 1.1548390551349097
# C T -0.3 -0.21898089912281246
# C G -1.0 -0.8155148609153633
# T A -1.2 -1.0107562311765241
# T C -0.4 -0.3533435188080809
# T T 1.0 0.9481424984994895
# T G -0.8 -0.7936991785294737
# G A -0.4 -0.3196488707470364
# G C -1.4 -0.849865472321773
# G T -0.9 -0.8236457884295995
# G G 1.3 1.2599158970104782
# [[1.         0.98982186]
#  [0.98982186 1.        ]]
# 0.10018168436468668
# -1.2 -1.1368995582847787
# -0.1 -0.09620325802826973
# -12 -11.264443720717527
# A A 1.0 0.9307426336857203
# A C -0.3 -0.2990609140810653
# A T -1.0 -0.8537890503430972
# A G -0.8 -0.7098320635619715
# C A -0.6 -0.5614821122866656
# C C 1.2 1.14421645453708
# C T -0.3 -0.2935889213808759
# C G -1.0 -0.8345672544547862
# T A -1.2 -1.147330254796779
# T C -0.4 -0.3248083087321767
# T T 1.0 0.9076282495960055
# T G -0.8 -0.8264563309619369
# G A -0.4 -0.42350519208323234
# G C -1.4 -1.040345053159639
# G T -0.9 -0.8102969639672719
# G G 1.3 1.2296651931374114
# [[1.         0.99583465]
#  [0.99583465 1.        ]]
# 0.08516300595778897

# %%
plt.figure(figsize=FIGSIZE)
plt.hist(rep_maes, bins=10, edgecolor = 'black', color = 'red')
plt.xlabel("Mean absolute error")
plt.ylabel("Number of replicates")
plt.tight_layout()
plt.savefig("results/general/replicates_mae_histogram_general.png", dpi=DPI)
plt.show()

plt.figure(figsize=FIGSIZE)
plt.boxplot(rep_maes)
plt.ylabel("Mean absolute error")
plt.xticks([])
plt.tight_layout()
plt.savefig("results/general/replicates_mae_boxplot_general.png", dpi=DPI)
plt.show()

plt.figure(figsize=FIGSIZE)
plt.hist(rep_corrs, bins=10, edgecolor = 'black', color = 'red')
plt.xlabel("Correlation")
plt.ylabel("Number of replicates")
plt.tight_layout()
plt.savefig("results/general/replicates_correlation_histogram_general.png", dpi=DPI)
plt.show()

plt.figure(figsize=FIGSIZE)
plt.boxplot(rep_corrs)
plt.ylabel("Correlation")
plt.xticks([])
plt.tight_layout()
plt.savefig("results/general/replicates_correlation_boxplot_general.png", dpi=DPI)
plt.show()

plt.figure(figsize=FIGSIZE)
plt.scatter(rep_maes, rep_corrs, color = 'red')
plt.xlabel("Mean absolute error")
plt.ylabel("Correlation")
plt.tight_layout()
plt.savefig("results/general/replicates_mae_vs_correlation_scatter_general.png", dpi=DPI)
plt.show()
